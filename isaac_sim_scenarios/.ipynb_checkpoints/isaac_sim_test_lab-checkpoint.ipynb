# %%
# Copyright (c) 2020-2021, NVIDIA CORPORATION.  All rights reserved.
#
# NVIDIA CORPORATION and its licensors retain all intellectual property
# and proprietary rights in and to this software, related documentation
# and any modifications thereto.  Any use, reproduction, disclosure or
# distribution of this software and related documentation without an express
# license agreement from NVIDIA CORPORATION is strictly prohibited.
# Cleanup application
simulation_app.close()

# %%
import getpass

user = getpass.getuser()
from isaacsim import SimulationApp

# Set the path below to your desired nucleus server
# Make sure you installed a local nucleus server before this
simulation_app = SimulationApp({"livesync_usd": f"omniverse://localhost/Users/yudaniel888/temp_jupyter_stage.usd"})
# Out:
# Starting kit application with the following args:  ['/home/bigcowfish/.local/share/ov/pkg/isaac-sim-4.1.0/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/home/bigcowfish/.local/share/ov/pkg/isaac-sim-4.1.0/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/home/bigcowfish/.local/share/ov/pkg/isaac-sim-4.1.0/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True', '--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=False', '--ext-folder', '/home/bigcowfish/.local/share/ov/pkg/isaac-sim-4.1.0/exts', '--ext-folder', '/home/bigcowfish/.local/share/ov/pkg/isaac-sim-4.1.0/apps', '--/physics/cudaDevice=0', '--portable', '--no-window', '--/app/window/hideUi=1']
# Passing the following args to the base kit application:  ['-f', '/home/bigcowfish/.local/share/jupyter/runtime/kernel-2a22f3b3-05eb-49a6-b5bd-df24e8971717.json']
# [Warning] [omni.isaac.kit.simulation_app] fast shutdown not supported with jupyter notebooks
# [Info] [carb] Logging to file: /home/bigcowfish/.local/share/ov/pkg/isaac-sim-4.1.0/kit/logs/Kit/Isaac-Sim/4.1/kit_20241112_150257.log
# 2024-11-12 07:02:57 s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [0.034s] [ext: omni.kit.async_engine-0.0.0] startup
# [0.228s] [ext: omni.stats-1.0.1] startup
# [0.229s] [ext: omni.client-1.1.0] startup
# [0.245s] [ext: omni.datastore-0.0.0] startup
# [0.245s] [ext: omni.blobkey-1.1.0] startup
# [0.245s] [ext: omni.ujitso.default-1.0.0] startup
# [0.245s] [ext: omni.hsscclient-0.0.0] startup
# [0.246s] [ext: omni.rtx.shadercache.vulkan-1.0.0] startup
# [0.246s] [ext: omni.assets.plugins-0.0.0] startup
# [0.247s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.251s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.255s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 550.120       | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4060 Ti       | Yes: 0 |     | 16380   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2803      | 812c854f.. |
# |     |                                  |        |     |            | 1         |            |
# |=============================================================================================|
# | OS: 22.04.5 LTS (Jammy Jellyfish) ubuntu, Version: 22.04.5, Kernel: 6.8.0-48-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101004 (1.21.1.4)
# | Processor: Intel(R) Core(TM) i7-14700KF | Cores: 20 | Logical: 40
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 31966 | Free Memory: 22951
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 2047
# |---------------------------------------------------------------------------------------------|
# [0.618s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.619s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.619s] [ext: omni.pip.compute-1.4.0] startup
# [0.620s] [ext: omni.kit.telemetry-0.5.0] startup
# [0.633s] [ext: omni.pip.cloud-1.1.3] startup
# [0.635s] [ext: omni.isaac.core_archive-2.3.0] startup
# [0.635s] [ext: omni.mtlx-0.1.0] startup
# [0.635s] [ext: omni.usd.config-1.0.4] startup
# [0.637s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.637s] [ext: omni.usd.libs-1.0.1] startup
# [0.685s] [ext: omni.isaac.ml_archive-2.0.1] startup
# [0.686s] [ext: omni.kit.loop-isaac-1.2.0] startup
# [0.686s] [ext: omni.kit.test-0.0.0] startup
# [0.703s] [ext: omni.appwindow-1.1.8] startup
# [0.704s] [ext: omni.kit.renderer.core-1.0.1] startup
# [0.938s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [0.939s] [ext: omni.kit.renderer.imgui-1.0.1] startup
# [1.255s] [ext: omni.ui-2.23.11] startup
# [1.261s] [ext: omni.kit.mainwindow-1.0.3] startup
# [1.262s] [ext: carb.audio-0.1.0] startup
# [1.264s] [ext: omni.uiaudio-1.0.0] startup
# [1.264s] [ext: omni.kit.uiapp-0.0.0] startup
# [1.264s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.314s] [ext: omni.anim.navigation.schema-106.0.2] startup
# [1.321s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.324s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.328s] [ext: omni.usd.schema.anim-0.0.0] startup
# [1.337s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.341s] [ext: omni.usd.schema.isaac-2.1.0] startup
# [1.345s] [ext: omni.usd.schema.scene.visualization-2.0.2] startup
# [1.345s] [ext: omni.usd.schema.physx-106.0.20] startup
# [1.368s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [1.371s] [ext: omni.anim.graph.schema-106.0.2] startup
# [1.375s] [ext: omni.usd.schema.forcefield-106.0.20] startup
# [1.378s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [1.380s] [ext: omni.graph.exec-0.9.3] startup
# [1.381s] [ext: omni.kit.widget.nucleus_connector-1.1.8] startup
# [1.382s] [ext: omni.kit.usd_undo-0.1.8] startup
# [1.382s] [ext: omni.kit.exec.core-0.13.2] startup
# [1.383s] [ext: omni.usd_resolver-1.0.0] startup
# [1.385s] [ext: omni.resourcemonitor-105.0.1] startup
# [1.387s] [ext: omni.kit.actions.core-1.0.0] startup
# [1.387s] [ext: omni.activity.core-1.0.1] startup
# [1.388s] [ext: omni.usd.core-1.2.11] startup
# [1.391s] [ext: omni.timeline-1.0.10] startup
# [1.391s] [ext: omni.kit.commands-1.4.9] startup
# [1.393s] [ext: usdrt.scenegraph-7.4.8] startup
# [1.419s] [ext: omni.kit.audiodeviceenum-1.0.1] startup
# [1.420s] [ext: omni.hydra.usdrt_delegate-7.4.7] startup
# [1.435s] [ext: omni.hydra.scene_delegate-0.3.3] startup
# [1.440s] [ext: omni.usd-1.11.2] startup
# [1.473s] [ext: omni.kit.notification_manager-1.0.8] startup
# [1.474s] [ext: omni.kit.clipboard-1.0.3] startup
# [1.474s] [ext: omni.kit.widget.path_field-2.0.9] startup
# [1.475s] [ext: omni.kit.collaboration.telemetry-1.0.0] startup
# [1.475s] [ext: omni.kit.helper.file_utils-0.1.8] startup
# [1.476s] [ext: omni.kit.widget.nucleus_info-1.0.2] startup
# [1.476s] [ext: omni.kit.widget.context_menu-1.2.1] startup
# [1.477s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [1.477s] [ext: omni.kit.collaboration.channel_manager-1.0.11] startup
# [1.478s] [ext: omni.kit.widget.filebrowser-2.10.48] startup
# [1.480s] [ext: omni.kit.search_core-1.0.5] startup
# [1.480s] [ext: omni.kit.widget.options_menu-1.1.4] startup
# [1.481s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [1.482s] [ext: omni.kit.widget.search_delegate-1.0.4] startup
# [1.482s] [ext: omni.ui.scene-1.9.3] startup
# [1.485s] [ext: omni.kit.widget.options_button-1.0.2] startup
# [1.485s] [ext: omni.kit.widget.settings-1.1.1] startup
# [1.486s] [ext: omni.kit.menu.utils-1.5.27] startup
# [1.492s] [ext: omni.kit.window.filepicker-2.10.34] startup
# [1.496s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [1.496s] [ext: omni.kit.usd.layers-2.1.31] startup
# [1.502s] [ext: omni.kit.window.preferences-1.5.3] startup
# [1.506s] [ext: omni.kit.widget.live_session_management.ui-1.0.1] startup
# [1.507s] [ext: omni.kit.collaboration.presence_layer-1.0.8] startup
# [1.508s] [ext: omni.kit.widget.live_session_management-1.2.18] startup
# [1.509s] [ext: omni.inspect-1.0.1] startup
# [1.510s] [ext: omni.kit.widget.graph-1.12.8] startup
# [1.512s] [ext: omni.kit.widget.filter-1.1.4] startup
# [1.513s] [ext: omni.graph.core-2.170.3] startup
# [1.515s] [ext: omni.kit.window.extensions-1.4.9] startup
# [1.517s] [ext: omni.kit.hotkeys.core-1.3.3] startup
# [1.518s] [ext: omni.kit.context_menu-1.8.0] startup
# [1.518s] [ext: omni.mdl-52.0.1] startup
# [1.529s] [ext: omni.iray.libs-0.0.0] startup
# [1.532s] [ext: omni.kit.primitive.mesh-1.0.16] startup
# [1.533s] [ext: omni.kit.stage_template.core-1.1.21] startup
# [1.534s] [ext: omni.mdl.neuraylib-0.2.5] startup
# [1.534s] [ext: omni.ujitso.processor.texture-1.0.0] startup
# [1.535s] [ext: omni.kit.window.file_exporter-1.0.29] startup
# [1.536s] [ext: omni.kit.stage_templates-1.2.3] startup
# [1.537s] [ext: omni.volume-0.5.0] startup
# [1.538s] [ext: omni.ujitso.client-0.0.0] startup
# [1.538s] [ext: omni.kit.window.file_importer-1.1.11] startup
# [1.539s] [ext: omni.kit.window.drop_support-1.0.2] startup
# [1.539s] [ext: omni.kit.window.file-1.3.52] startup
# [1.541s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [1.541s] [ext: omni.hydra.rtx-0.2.0] startup
# [1.550s] [ext: omni.kit.widget.highlight_label-1.0.2] startup
# [1.551s] [ext: omni.kit.window.content_browser-2.9.14] startup
# [1.559s] [ext: omni.kit.widget.stage-2.10.26] startup
# [1.565s] [ext: omni.kit.material.library-1.4.4] startup
# [1.568s] [ext: omni.kit.hydra_texture-1.2.6] startup
# [1.571s] [ext: omni.kit.viewport.legacy_gizmos-1.0.15] startup
# [1.574s] [ext: omni.kit.raycast.query-1.0.5] startup
# [1.579s] [ext: omni.hydra.engine.stats-1.0.2] startup
# [1.582s] [ext: omni.kit.widget.search
# Warning: Possible version incompatibility. Attempting to load omni::fabric::IPath with version v0.2 against v0.1.
# Warning: Possible version incompatibility. Attempting to load omni::fabric::IPath with version v0.2 against v0.1.
# field-1.1.6] startup
# [1.583s] [ext: omni.kit.widget.viewport-106.0.3] startup
# [1.585s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [1.585s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [1.586s] [ext: omni.kit.viewport.window-106.0.8] startup
# [1.596s] [ext: omni.kit.window.property-1.11.1] startup
# [1.597s] [ext: omni.usdphysics-106.0.20] startup
# [1.599s] [ext: omni.graph.tools-1.78.0] startup
# [1.610s] [ext: omni.kit.viewport.utility-1.0.17] startup
# [1.610s] [ext: omni.kit.property.usd-3.21.28] startup
# [1.615s] [ext: omni.graph-1.135.0] startup
# [1.676s] [ext: omni.graph.image.core-0.3.2] startup
# [1.679s] [ext: omni.graph.ui-1.70.0] startup
# [1.703s] [ext: omni.graph.action_core-1.1.4] startup
# [1.709s] [ext: omni.kit.window.cursor-1.1.2] startup
# [1.710s] [ext: omni.graph.image.nodes-1.0.2] startup
# [1.711s] [ext: omni.graph.action_nodes-1.23.0] startup
# [1.716s] [ext: omni.kit.viewport.menubar.core-106.0.2] startup
# [1.729s] [ext: omni.graph.nodes-1.143.0] startup
# [1.737s] [ext: omni.graph.action-1.102.1] startup
# [1.739s] [ext: omni.warp.core-1.2.1] startup
# [1.804s] [ext: omni.syntheticdata-0.6.7] startup
# [1.832s] [ext: omni.warp-1.2.1] startup
# [1.850s] [ext: omni.kvdb-106.0.20] startup
# [1.858s] [ext: omni.physx.foundation-106.0.20] startup
# [1.859s] [ext: omni.localcache-106.0.20] startup
# [1.861s] [ext: omni.convexdecomposition-106.0.20] startup
# [1.870s] [ext: omni.sensors.tiled-0.0.4] startup
# [1.874s] [ext: omni.physx.cooking-106.0.20] startup
# [1.887s] [ext: omni.kit.viewport.actions-106.0.3] startup
# [1.905s] [ext: omni.debugdraw-0.1.3] startup
# [1.912s] [ext: omni.physx-106.0.20] startup
# [1.935s] [ext: omni.kit.viewport.menubar.display-106.0.2] startup
# [1.944s] [ext: omni.kit.manipulator.transform-104.7.5] startup
# [1.950s] [ext: omni.kit.widget.toolbar-1.6.2] startup
# [2.057s] [ext: omni.physx.stageupdate-106.0.20] startup
# [2.060s] [ext: omni.usdphysics.ui-106.0.20] startup
# [2.075s] [ext: omni.physx.commands-106.0.20] startup
# [2.078s] [ext: omni.kit.manipulator.tool.snap-1.4.5] startup
# [2.082s] [ext: omni.kit.property.material-1.9.4] startup
# [2.084s] [ext: omni.physx.ui-106.0.20] startup
# [2.102s] [ext: omni.kit.manipulator.selector-1.1.1] startup
# [2.104s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [2.105s] [ext: omni.kit.manipulator.viewport-107.0.0] startup
# [2.106s] [ext: omni.kit.property.physx-106.0.20] startup
# [2.150s] [ext: omni.physx.demos-106.0.20] startup
# [2.161s] [ext: omni.kit.viewport.manipulator.transform-106.0.1] startup
# [2.163s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [2.164s] [ext: omni.ui_query-1.1.2] startup
# [2.165s] [ext: omni.fabric.commands-1.1.4] startup
# [2.168s] [ext: omni.physx.vehicle-106.0.20] startup
# [2.179s] [ext: omni.kit.manipulator.prim.core-107.0.3] startup
# [2.183s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [2.185s] [ext: omni.kit.ui_test-1.2.18] startup
# [2.186s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [2.187s] [ext: omni.physx.camera-106.0.20] startup
# [2.193s] [ext: omni.kit.manipulator.prim.fabric-106.0.1] startup
# [2.195s] [ext: omni.kit.manipulator.prim.usd-106.0.1] startup
# [2.196s] [ext: omni.physx.cct-106.0.20] startup
# [2.202s] [ext: omni.physics.tensors-106.0.20] startup
# [2.209s] [ext: omni.isaac.version-1.1.0] startup
# [2.210s] [ext: omni.kit.manipulator.selection-104.0.9] startup
# [2.211s] [ext: omni.kit.manipulator.prim-106.0.0] startup
# [2.211s] [ext: omni.command.usd-1.0.3] startup
# [2.212s] [ext: omni.physx.tensors-106.0.20] startup
# [2.215s] [ext: omni.isaac.nucleus-0.3.0] startup
# [2.216s] [ext: omni.kit.window.toolbar-1.6.1] startup
# [2.218s] [ext: omni.kit.widget.layers-1.7.9] startup
# [2.224s] [ext: omni.physx.graph-106.0.20] startup
# [2.233s] [ext: omni.physx.supportui-106.0.20] startup
# [2.246s] [ext: omni.physx.telemetry-106.0.20] startup
# [2.249s] [ext: omni.graph.scriptnode-1.19.1] startup
# [2.250s] [ext: omni.graph.ui_nodes-1.25.1] startup
# [2.254s] [ext: omni.kit.numpy.common-0.1.2] startup
# [2.257s] [ext: omni.physx.bundle-106.0.20] startup
# [2.257s] [ext: omni.kit.window.material_graph-1.8.15] startup
# [2.286s] [ext: omni.graph.bundle.actWarp 1.2.1 initialized:
#    CUDA Toolkit 11.8, Driver 12.4
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA GeForce RTX 4060 Ti" (16 GiB, sm_89, mempool enabled)
#    Kernel cache:
#      /home/bigcowfish/.cache/warp/1.2.1
# ion-2.0.4] startup
# [2.287s] [ext: omni.isaac.dynamic_control-1.3.8] startup
# [2.297s] [ext: omni.replicator.core-1.11.14] startup
# 2024-11-12 07:03:00 [2,389ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registered, overwriting annotator template
# [2.464s] [ext: omni.isaac.core-3.18.1] startup
# [3.244s] [ext: omni.graph.visualization.nodes-2.1.1] startup
# [3.250s] [ext: omni.isaac.core_nodes-1.16.1] startup
# [3.258s] [ext: omni.isaac.cloner-0.8.1] startup
# [3.261s] [ext: omni.isaac.ui-0.16.0] startup
# [3.273s] [ext: omni.kit.graph.widget.variables-2.1.0] startup
# [3.277s] [ext: omni.kit.graph.delegate.modern-1.10.6] startup
# [3.280s] [ext: omni.isaac.wheeled_robots-2.3.3] startup
# [3.289s] [ext: omni.isaac.gym-0.11.3] startup
# [3.292s] [ext: omni.graph.window.core-1.109.0] startup
# [3.306s] [ext: omni.isaac.debug_draw-1.1.0] startup
# [3.311s] [ext: omni.isaac.block_world-1.0.0] startup
# [3.315s] [ext: omni.graph.window.generic-1.24.0] startup
# [3.325s] [ext: omni.isaac.menu-0.5.0] startup
# [3.329s] [ext: omni.isaac.occupancy_map-1.0.2] startup
# [3.337s] [ext: omni.importer.mjcf-1.1.1] startup
# [3.343s] [ext: omni.graph.window.action-1.26.0] startup
# [3.348s] [ext: omni.kit.widget.live-2.1.6] startup
# [3.349s] [ext: omni.kit.actions.window-1.1.1] startup
# [3.351s] [ext: omni.kit.ui.actions-1.0.1] startup
# [3.352s] [ext: omni.kit.widget.cache_indicator-2.0.8] startup
# [3.384s] [ext: omni.kit.hotkeys.window-1.4.5] startup
# [3.387s] [ext: omni.kit.selection-0.1.4] startup
# [3.388s] [ext: omni.kit.menu.common-1.1.5] startup
# [3.389s] [ext: omni.sensors.nv.common-1.2.2-isaac] startup
# [3.397s] [ext: omni.isaac.kit-1.13.0] startup
# [3.397s] [ext: omni.kit.menu.edit-1.1.24] startup
# [3.400s] [ext: omni.kit.menu.file-1.1.10] startup
# [3.402s] [ext: omni.isaac.range_sensor-3.1.1] startup
# [3.410s] [ext: omni.sensors.nv.materials-1.2.1-isaac] startup
# [3.412s] [ext: omni.kit.property.audio-1.0.11] startup
# [3.413s] [ext: omni.kit.widget.stage_icons-1.0.4] startup
# [3.415s] [ext: omni.kit.property.geometry-1.3.0] startup
# [3.417s] [ext: omni.kit.property.camera-1.0.6] startup
# [3.418s] [ext: omni.sensors.nv.lidar-1.2.2-isaac] startup
# [3.422s] [ext: omni.sensors.nv.wpm-1.2.1-isaac] startup
# [3.423s] [ext: omni.hydra.scene_api-0.1.2] startup
# [3.428s] [ext: omni.kit.window.stage-2.5.10] startup
# [3.430s] [ext: omni.kit.property.render-1.1.1] startup
# [3.432s] [ext: omni.kit.property.light-1.0.8] startup
# [3.433s] [ext: omni.sensors.nv.radar-1.2.1-isaac] startup
# [3.437s] [ext: omni.kit.property.transform-1.5.1] startup
# [3.439s] [ext: omni.kit.menu.stage-1.2.5] startup
# [3.440s] [ext: omni.kit.profiler.window-2.2.1] startup
# 2024-11-12 07:03:01 [3,434ms] [Warning] [omni.kit.profiler.window] remove _SpanInstance.__lt__ and use insort 'key' arg instead
# [3.446s] [ext: omni.kit.property.bundle-1.2.11] startup
# [3.447s] [ext: omni.kit.property.isaac-0.2.3] startup
# [3.449s] [ext: omni.isaac.sensor-12.7.1] startup
# [3.493s] [ext: omni.isaac.surface_gripper-1.0.1] startup
# [3.498s] [ext: omni.kit.stage_column.payload-2.0.0] startup
# [3.502s] [ext: omni.kit.property.layer-1.1.6] startup
# [3.507s] [ext: omni.isaac.scene_blox-0.1.2] startup
# [3.510s] [ext: omni.isaac.quadruped-1.4.5] startup
# [3.526s] [ext: omni.isaac.manipulators-2.1.0] startup
# [3.533s] [ext: omni.isaac.lula-3.0.1] startup
# [3.540s] [ext: omni.kit.viewport.menubar.render-106.1.3] startup
# [3.544s] [ext: omni.kit.viewport.menubar.settings-106.0.1] startup
# [3.552s] [ext: omni.kit.viewport.menubar.camera-105.1.8] startup
# [3.555s] [ext: omni.kit.manipulator.camera-105.0.5] startup
# [3.557s] [ext: omni.isaac.motion_generation-7.1.0] startup
# [3.560s] [ext: omni.kit.widget.calendar-1.0.8] startup
# [3.562s] [ext: omni.kit.stage_column.variant-1.0.13] startup
# [3.563s] [ext: omni.kit.viewport.bundle-104.0.1] startup
# [3.563s] [ext: omni.isaac.universal_robots-0.3.5] startup
# [3.564s] [ext: omni.kit.widget.extended_searchfield-1.0.28] startup
# [3.571s] [ext: omni.kit.widget.timeline-105.0.1] startup
# [3.574s] [ext: omni.kit.window.commands-0.2.5] startup
# [3.575s] [ext: omni.kit.window.console-0.2.12Saving a temp livesync stage at  omniverse://localhost/Users/yudaniel888/temp_jupyter_stage.usd  ...Done.
# ] startup
# [3.582s] [ext: omni.kit.window.script_editor-1.7.6] startup
# [3.584s] [ext: omni.kit.menu.create-1.0.13] startup
# [3.585s] [ext: omni.kit.window.status_bar-0.1.6] startup
# [3.588s] [ext: omni.rtx.window.settings-0.6.16] startup
# [3.591s] [ext: omni.isaac.franka-0.4.1] startup
# [3.592s] [ext: omni.kit.window.title-1.1.3] startup
# [3.594s] [ext: omni.replicator.isaac-1.15.0] startup
# [3.603s] [ext: omni.replicator.replicator_yaml-2.0.5] startup
# [3.616s] [ext: omni.rtx.settings.core-0.6.0] startup
# [3.630s] [ext: omni.isaac.cortex-0.3.8] startup
# [3.632s] [ext: omni.kit.viewport.menubar.lighting-106.0.2] startup
# [3.637s] [ext: semantics.schema.editor-0.3.6] startup
# [3.641s] [ext: semantics.schema.property-1.0.3] startup
# [3.642s] [ext: omni.kit.viewport.rtx-104.0.1] startup
# [3.642s] [ext: omni.isaac.utils-1.0.1] startup
# [3.644s] [ext: omni.isaac.cortex.sample_behaviors-1.0.5] startup
# [3.645s] [ext: omni.importer.urdf-1.14.1] startup
# [3.678s] [ext: omni.kit.window.stats-0.1.6] startup
# [3.683s] [ext: omni.isaac.sim.python-4.1.0] startup
# [3.684s] Simulation App Starting
# [7.599s] app ready
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.local/share/ov/pkg/isaac-sim-4.1.0/kit/exts/omni.kit.widget.live/omni/kit/widget/live/live_state_menu.py:77, in LiveStateDelegate._on_layer_event(self, event)
#      74 if not payload.is_layer_influenced(self._usd_context.get_stage_url()):
#      75     return
# ---> 77 self.__update_live_tooltip()
#
# File ~/.local/share/ov/pkg/isaac-sim-4.1.0/kit/exts/omni.kit.widget.live/omni/kit/widget/live/live_state_menu.py:168, in LiveStateDelegate.__update_live_tooltip(self)
#     166 peer_users_count = len(current_session.peer_users)
#     167 if peer_users_count > 0:
# --> 168     self._live_background.set_tooltip(
#     169         f"Leave Session {current_session.name}\n{peer_users_count + 1} Total Users in Session"
#     170     )
#     171 else:
#     172     self._live_background.set_tooltip(
#     173         f"Leave Session {current_session.name}"
#     174     )
#
# AttributeError: 'NoneType' object has no attribute 'set_tooltip'

# %%
from omni.isaac.core import World
from omni.isaac.core.objects import DynamicCuboid
import numpy as np

from omni.isaac.franka import Franka
from omni.isaac.franka.controllers import PickPlaceController
from omni.isaac.franka.controllers.stacking_controller import StackingController
from omni.isaac.franka.tasks import Stacking

from omni.isaac.sensor import Camera

import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from omni.isaac.sensor import Camera

# %%
world = World(stage_units_in_meters=1.0)
world.scene.add_default_ground_plane()
# A render/ step or an update call is needed to reflect the changes to the opened USD in Isaac Sim GUI
#  Note: avoid pressing play/ pause or stop in the GUI in this workflow.

#Da Cameraaaaaaaaaa lahhhhhhhhhhhhhhhhhhh
resolution = (1920, 1080)
camera = world.scene.add(Camera(prim_path="/World/Fancy_Camera", name="fancy_camera", position=np.array([-5.0, 0.0, 0.4]), orientation=np.array([1.0, 0.0, 0.0, 0.0]), resolution=resolution))
franka = world.scene.add(Franka(prim_path="/World/Fancy_Franka", name="fancy_franka"))
fancy_cube = world.scene.add(
    DynamicCuboid(
        prim_path="/World/random_cube",
        name="fancy_cube",
        position=np.array([0.3, 0.3, 0.3]),
        orientation=np.array([1, 0, 0, 0]),
        scale=np.array([0.05015, 0.05015, 0.05015]),
        size=1.0,
        color=np.array([0, 0, 1.0]),
    )
)
plate_1 = world.scene.add(
    DynamicCuboid(
        prim_path="/World/plate_1",
        name="plate_1",
        position=np.array([0.5, 0.5, 0.0]),
        scale=np.array([0.2, 0.2, 0.01]),
        size=1.0,
        color=np.array([0, 1.0, 0.0]),
    )
)
world.render()
world.reset()

# %%
# This opens the franka finger
world.reset()
franka.gripper.set_joint_positions(franka.gripper.joint_opened_positions)

for i in range(10):
    print(franka.gripper.get_joint_positions())
    world.step(render=True)  # execute one physics step and one rendering step
    
world.render()
# Out:
# [0.05 0.05]
# [0.03999998 0.04      ]
# [0.04 0.04]
# [0.04 0.04]
# [0.04 0.04]
# [0.04 0.04]
# [0.04 0.04]
# [0.04 0.04]
# [0.04 0.04]
# [0.04 0.04]

# %%
# This closes the franka finger
world.reset()
franka.gripper.set_joint_positions(franka.gripper.joint_closed_positions)

for i in range(10):
    print(franka.gripper.get_joint_positions())
    world.step(render=True)  # execute one physics step and one rendering step
    
world.render()
# Out:
# [0. 0.]
# [9.0769836e-09 1.4597541e-08]
# [1.1288139e-08 5.9437366e-09]
# [2.6060096e-08 2.4653152e-08]
# [2.1479543e-08 1.9357927e-08]
# [1.8931997e-08 1.7518314e-08]
# [1.6839682e-08 1.5424702e-08]
# [1.5182820e-08 1.3765865e-08]
# [1.39726515e-08 1.34758800e-08]
# [1.3267912e-08 1.0263303e-08]

# %%
# Set franka controller
franka_controller = PickPlaceController(name="pick_place_controller", gripper=franka.gripper, robot_articulation=franka,)
print(franka_controller.is_done())
# Out:
# False

# %%
# Franka reset
franka_controller.reset()
franka.gripper.set_joint_positions(franka.gripper.joint_opened_positions)

for i in range(10):
    print(franka.gripper.get_joint_positions())
    world.step(render=True)  # execute one physics step and one rendering step
# Out:
# [0.05 0.05]
# [0.03999999 0.04      ]
# [0.04 0.04]
# [0.04 0.04]
# [0.04 0.04]
# [0.04 0.04]
# [0.04 0.04]
# [0.04 0.04]
# [0.04 0.04]
# [0.04 0.04]

# %%
# Trying out camera
import matplotlib.pyplot as plt
camera.initialize()
#print(camera)
rgb_array = camera.get_rgb();
plt.imshow(rgb_array)
plt.axis("off")  # Hide the axes
plt.show()

# %%
# Cube moving experiment
# TODO: Set random start position between x = 0.3 to 0.5, y = 0.1 to 0.3
# TODO: Set random end position between x = -0.3 to -0.5, y = -0.1 to -0.3
import random
# One iteration

def physical_step(da_cube, da_bot, da_control, goal_position):
    # TODO: Add a goal position
    # Feedback
    cube_position, _ = da_cube.get_world_pose()
    goal_position = goal_position + np.array([0, 0, 0.0615 / 2.0])
    current_joint_positions = da_bot.get_joint_positions()
    actions = da_control.forward(
        picking_position=cube_position,
        placing_position=goal_position,
        current_joint_positions=current_joint_positions,
    )

    da_bot.apply_action(actions)
    # Only for the pick and place controller, indicating if the state
    # machine reached the final state.
    return da_control.is_done()

def randomize_starting_position(world, fancy_cube, plate_1):
    world.reset()
    fancy_cube.set_world_pose(position=[random.uniform(0.3, 0.5), random.uniform(0.1, 0.3), 0.0])
    goal_position = np.array([random.uniform(-0.3, -0.5), random.uniform(-0.3, -0.5), 0.0])
    plate_1.set_world_pose(position=goal_position)
    return goal_position

def freeze_to_update(world):
    for i in range(10):
        world.step(render=True)  # execute one physics step and one rendering step
        

#world.reset()
#fancy_cube.set_world_pose(position=[random.uniform(0.3, 0.5), random.uniform(0.1, 0.3), 0.0])
#goal_position = np.array([random.uniform(-0.3, -0.5), random.uniform(-0.3, -0.5), 0.0])
#plate_1.set_world_pose(position=goal_position)

goal_position = randomize_starting_position(world, fancy_cube, plate_1)
freeze_to_update(world)

# %%
# One time test
franka_controller.reset()
franka.gripper.set_joint_positions(franka.gripper.joint_opened_positions) 

# Video related
# Initialize variables
frames = []
# Directory to save images
output_images_dir = "4"
os.makedirs(output_images_dir, exist_ok=True)  # Create the directory if it doesn't exist

until = 70;

for i in range(5000):
    if i % until == 0:
        rgb_array = camera.get_rgb();
        # Convert RGB to BGR format for OpenCV compatibility
        bgr_array = cv2.cvtColor(rgb_array, cv2.COLOR_RGB2BGR)
        # Define filename for each frame
        filename = os.path.join(output_images_dir, f"frame_{i:04d}.png")
        # Save the image
        cv2.imwrite(filename, bgr_array)
        frames.append(rgb_array)
    if physical_step(fancy_cube, franka, franka_controller, goal_position):
        world.step(render=True)  # execute one physics step and one rendering step
        print("Doneee")
        break
    #position, orientation = fancy_cube.get_world_pose()
    #linear_velocity = fancy_cube.get_linear_velocity()
    #print("Cube position is : " + str(position))
    #print("Cube's orientation is : " + str(orientation))
    #print("Cube's linear velocity is : " + str(linear_velocity))
    # we have control over stepping physics and rendering in this workflow
    # things run in sync
    world.step(render=True)  # execute one physics step and one rendering step
# Out:
# Doneee

# %%
# Testing and training data collection
number_of_video_datas = 25;
until = 25;

for i in range(number_of_video_datas):
    print("start collecting video", i)
    goal_position = randomize_starting_position(world, fancy_cube, plate_1)
    freeze_to_update(world);
    
    franka_controller.reset()
    franka.gripper.set_joint_positions(franka.gripper.joint_opened_positions) 
    
    # Video related
    # Initialize variables
    frames = []
    # Directory to save images
    output_images_dir = str(i)
    os.makedirs(output_images_dir, exist_ok=True)  # Create the directory if it doesn't exist
    
    for j in range(5000):
        if j % until == 0:
            rgb_array = camera.get_rgb();
            # Convert RGB to BGR format for OpenCV compatibility
            bgr_array = cv2.cvtColor(rgb_array, cv2.COLOR_RGB2BGR)
            # Define filename for each frame
            filename = os.path.join(output_images_dir, f"frame_{j:04d}.png")
            # Save the image
            cv2.imwrite(filename, bgr_array)
            frames.append(rgb_array)
        if physical_step(fancy_cube, franka, franka_controller, goal_position):
            world.step(render=True)  # execute one physics step and one rendering step
            print("Doneee")
            break
        #position, orientation = fancy_cube.get_world_pose()
        #linear_velocity = fancy_cube.get_linear_velocity()
        #print("Cube position is : " + str(position))
        #print("Cube's orientation is : " + str(orientation))
        #print("Cube's linear velocity is : " + str(linear_velocity))
        # we have control over stepping physics and rendering in this workflow
        # things run in sync
        world.step(render=True)  # execute one physics step and one rendering step
        
    print("Doneeee collecting video", i)
# Out:
# start collecting video 0
# Doneee
# Doneeee collecting video 0
# start collecting video 1
# Doneee
# Doneeee collecting video 1
# start collecting video 2
# Doneee
# Doneeee collecting video 2
# start collecting video 3
# Doneee
# Doneeee collecting video 3
# start collecting video 4
# Doneee
# Doneeee collecting video 4
# start collecting video 5
# Doneee
# Doneeee collecting video 5
# start collecting video 6
# Doneee
# Doneeee collecting video 6
# start collecting video 7
# Doneee
# Doneeee collecting video 7
# start collecting video 8
# Doneee
# Doneeee collecting video 8
# start collecting video 9
# Doneee
# Doneeee collecting video 9
# start collecting video 10
# Doneee
# Doneeee collecting video 10
# start collecting video 11
# Doneee
# Doneeee collecting video 11
# start collecting video 12
# Doneee
# Doneeee collecting video 12
# start collecting video 13
# Doneee
# Doneeee collecting video 13
# start collecting video 14
# Doneee
# Doneeee collecting video 14
# start collecting video 15
# Doneee
# Doneeee collecting video 15
# start collecting video 16
# Doneee
# Doneeee collecting video 16
# start collecting video 17
# Doneee
# Doneeee collecting video 17
# start collecting video 18
# Doneee
# Doneeee collecting video 18
# start collecting video 19
# Doneee
# Doneeee collecting video 19
# start collecting video 20
# Doneee
# Doneeee collecting video 20
# start collecting video 21
# Doneee
# Doneeee collecting video 21
# start collecting video 22
# Doneee
# Doneeee collecting video 22
# start collecting video 23
# Doneee
# Doneeee collecting video 23
# start collecting video 24
# Doneee
# Doneeee collecting video 24

# %%
world.reset()

# %%
# Cleanup application
simulation_app.close()

# %%
# Copyright (c) 2020-2021, NVIDIA CORPORATION.  All rights reserved.
#
# NVIDIA CORPORATION and its licensors retain all intellectual property
# and proprietary rights in and to this software, related documentation
# and any modifications thereto.  Any use, reproduction, disclosure or
# distribution of this software and related documentation without an express
# license agreement from NVIDIA CORPORATION is strictly prohibited.

# %%
import getpass

user = getpass.getuser()
from isaacsim import SimulationApp

# Set the path below to your desired nucleus server
# Make sure you installed a local nucleus server before this
simulation_app = SimulationApp({"livesync_usd": f"omniverse://localhost/Users/yudaniel888/temp_jupyter_stage.usd"})
# Out:
# Starting kit application with the following args:  ['/home/bigcowfish/.local/share/ov/pkg/isaac-sim-4.1.0/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/home/bigcowfish/.local/share/ov/pkg/isaac-sim-4.1.0/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/home/bigcowfish/.local/share/ov/pkg/isaac-sim-4.1.0/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True', '--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=False', '--ext-folder', '/home/bigcowfish/.local/share/ov/pkg/isaac-sim-4.1.0/exts', '--ext-folder', '/home/bigcowfish/.local/share/ov/pkg/isaac-sim-4.1.0/apps', '--/physics/cudaDevice=0', '--portable', '--no-window', '--/app/window/hideUi=1']
# Passing the following args to the base kit application:  ['-f', '/home/bigcowfish/.local/share/jupyter/runtime/kernel-0d9b8014-6e98-4e80-b3f8-22efff7d0470.json']
# [Warning] [omni.isaac.kit.simulation_app] fast shutdown not supported with jupyter notebooks
# [Info] [carb] Logging to file: /home/bigcowfish/.local/share/ov/pkg/isaac-sim-4.1.0/kit/logs/Kit/Isaac-Sim/4.1/kit_20241030_180839.log
# 2024-10-30 10:08:39 s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [0.031s] [ext: omni.kit.async_engine-0.0.0] startup
# [0.222s] [ext: omni.stats-1.0.1] startup
# [0.222s] [ext: omni.client-1.1.0] startup
# [0.239s] [ext: omni.datastore-0.0.0] startup
# [0.239s] [ext: omni.blobkey-1.1.0] startup
# [0.239s] [ext: omni.ujitso.default-1.0.0] startup
# [0.239s] [ext: omni.hsscclient-0.0.0] startup
# [0.240s] [ext: omni.rtx.shadercache.vulkan-1.0.0] startup
# [0.240s] [ext: omni.assets.plugins-0.0.0] startup
# [0.241s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.246s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.252s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 550.107.02    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4060 Ti       | Yes: 0 |     | 16380   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2803      | 812c854f.. |
# |     |                                  |        |     |            | 1         |            |
# |=============================================================================================|
# | OS: 22.04.5 LTS (Jammy Jellyfish) ubuntu, Version: 22.04.5, Kernel: 6.8.0-47-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101004 (1.21.1.4)
# | Processor: Intel(R) Core(TM) i7-14700KF | Cores: 20 | Logical: 40
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 31966 | Free Memory: 19452
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 1838
# |---------------------------------------------------------------------------------------------|
# [0.616s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.617s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.618s] [ext: omni.pip.compute-1.4.0] startup
# [0.618s] [ext: omni.kit.telemetry-0.5.0] startup
# [0.637s] [ext: omni.pip.cloud-1.1.3] startup
# [0.641s] [ext: omni.isaac.core_archive-2.3.0] startup
# [0.641s] [ext: omni.mtlx-0.1.0] startup
# [0.642s] [ext: omni.usd.config-1.0.4] startup
# [0.647s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.647s] [ext: omni.usd.libs-1.0.1] startup
# [0.703s] [ext: omni.isaac.ml_archive-2.0.1] startup
# [0.704s] [ext: omni.kit.loop-isaac-1.2.0] startup
# [0.704s] [ext: omni.kit.test-0.0.0] startup
# [0.721s] [ext: omni.appwindow-1.1.8] startup
# [0.722s] [ext: omni.kit.renderer.core-1.0.1] startup
# [0.984s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [0.985s] [ext: omni.kit.renderer.imgui-1.0.1] startup
# [1.259s] [ext: omni.ui-2.23.11] startup
# [1.265s] [ext: omni.kit.mainwindow-1.0.3] startup
# [1.266s] [ext: carb.audio-0.1.0] startup
# [1.268s] [ext: omni.uiaudio-1.0.0] startup
# [1.268s] [ext: omni.kit.uiapp-0.0.0] startup
# [1.268s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.320s] [ext: omni.anim.navigation.schema-106.0.2] startup
# [1.327s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.329s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.333s] [ext: omni.usd.schema.anim-0.0.0] startup
# [1.343s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.347s] [ext: omni.usd.schema.isaac-2.1.0] startup
# [1.351s] [ext: omni.usd.schema.scene.visualization-2.0.2] startup
# [1.352s] [ext: omni.usd.schema.physx-106.0.20] startup
# [1.377s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [1.380s] [ext: omni.anim.graph.schema-106.0.2] startup
# [1.384s] [ext: omni.usd.schema.forcefield-106.0.20] startup
# [1.387s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [1.390s] [ext: omni.graph.exec-0.9.3] startup
# [1.390s] [ext: omni.kit.widget.nucleus_connector-1.1.8] startup
# [1.391s] [ext: omni.kit.usd_undo-0.1.8] startup
# [1.391s] [ext: omni.kit.exec.core-0.13.2] startup
# [1.393s] [ext: omni.usd_resolver-1.0.0] startup
# [1.395s] [ext: omni.resourcemonitor-105.0.1] startup
# [1.396s] [ext: omni.kit.actions.core-1.0.0] startup
# [1.397s] [ext: omni.activity.core-1.0.1] startup
# [1.398s] [ext: omni.usd.core-1.2.11] startup
# [1.401s] [ext: omni.timeline-1.0.10] startup
# [1.402s] [ext: omni.kit.commands-1.4.9] startup
# [1.403s] [ext: usdrt.scenegraph-7.4.8] startup
# [1.431s] [ext: omni.kit.audiodeviceenum-1.0.1] startup
# [1.431s] [ext: omni.hydra.usdrt_delegate-7.4.7] startup
# [1.446s] [ext: omni.hydra.scene_delegate-0.3.3] startup
# [1.451s] [ext: omni.usd-1.11.2] startup
# [1.486s] [ext: omni.kit.notification_manager-1.0.8] startup
# [1.487s] [ext: omni.kit.clipboard-1.0.3] startup
# [1.488s] [ext: omni.kit.widget.path_field-2.0.9] startup
# [1.488s] [ext: omni.kit.collaboration.telemetry-1.0.0] startup
# [1.489s] [ext: omni.kit.helper.file_utils-0.1.8] startup
# [1.489s] [ext: omni.kit.widget.nucleus_info-1.0.2] startup
# [1.490s] [ext: omni.kit.widget.context_menu-1.2.1] startup
# [1.490s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [1.491s] [ext: omni.kit.collaboration.channel_manager-1.0.11] startup
# [1.491s] [ext: omni.kit.widget.filebrowser-2.10.48] startup
# [1.493s] [ext: omni.kit.search_core-1.0.5] startup
# [1.494s] [ext: omni.kit.widget.options_menu-1.1.4] startup
# [1.495s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [1.495s] [ext: omni.kit.widget.search_delegate-1.0.4] startup
# [1.496s] [ext: omni.ui.scene-1.9.3] startup
# [1.499s] [ext: omni.kit.widget.options_button-1.0.2] startup
# [1.499s] [ext: omni.kit.widget.settings-1.1.1] startup
# [1.500s] [ext: omni.kit.menu.utils-1.5.27] startup
# [1.507s] [ext: omni.kit.window.filepicker-2.10.34] startup
# [1.510s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [1.511s] [ext: omni.kit.usd.layers-2.1.31] startup
# [1.516s] [ext: omni.kit.window.preferences-1.5.3] startup
# [1.520s] [ext: omni.kit.widget.live_session_management.ui-1.0.1] startup
# [1.521s] [ext: omni.kit.collaboration.presence_layer-1.0.8] startup
# [1.523s] [ext: omni.kit.widget.live_session_management-1.2.18] startup
# [1.524s] [ext: omni.inspect-1.0.1] startup
# [1.525s] [ext: omni.kit.widget.graph-1.12.8] startup
# [1.527s] [ext: omni.kit.widget.filter-1.1.4] startup
# [1.528s] [ext: omni.graph.core-2.170.3] startup
# [1.530s] [ext: omni.kit.window.extensions-1.4.9] startup
# [1.533s] [ext: omni.kit.hotkeys.core-1.3.3] startup
# [1.533s] [ext: omni.kit.context_menu-1.8.0] startup
# [1.534s] [ext: omni.mdl-52.0.1] startup
# [1.544s] [ext: omni.iray.libs-0.0.0] startup
# [1.548s] [ext: omni.kit.primitive.mesh-1.0.16] startup
# [1.549s] [ext: omni.kit.stage_template.core-1.1.21] startup
# [1.550s] [ext: omni.mdl.neuraylib-0.2.5] startup
# [1.550s] [ext: omni.ujitso.processor.texture-1.0.0] startup
# [1.551s] [ext: omni.kit.window.file_exporter-1.0.29] startup
# [1.552s] [ext: omni.kit.stage_templates-1.2.3] startup
# [1.553s] [ext: omni.volume-0.5.0] startup
# [1.554s] [ext: omni.ujitso.client-0.0.0] startup
# [1.555s] [ext: omni.kit.window.file_importer-1.1.11] startup
# [1.555s] [ext: omni.kit.window.drop_support-1.0.2] startup
# [1.555s] [ext: omni.kit.window.file-1.3.52] startup
# [1.557s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [1.557s] [ext: omni.hydra.rtx-0.2.0] startup
# [1.567s] [ext: omni.kit.widget.highlight_label-1.0.2] startup
# [1.567s] [ext: omni.kit.window.content_browser-2.9.14] startup
# [1.576s] [ext: omni.kit.widget.stage-2.10.26] startup
# [1.582s] [ext: omni.kit.material.library-1.4.4] startup
# [1.586s] [ext: omni.kit.hydra_texture-1.2.6] startup
# [1.589s] [ext: omni.kit.viewport.legacy_gizmos-1.0.15] startup
# [1.592s] [ext: omni.kit.raycast.query-1.0.5] startup
# [1.597s] [ext: omni.hydra.engine.stats-1.0.2] startup
# [1.600s] [ext: omni.kit.widget.search
# Warning: Possible version incompatibility. Attempting to load omni::fabric::IPath with version v0.2 against v0.1.
# Warning: Possible version incompatibility. Attempting to load omni::fabric::IPath with version v0.2 against v0.1.
# field-1.1.6] startup
# [1.602s] [ext: omni.kit.widget.viewport-106.0.3] startup
# [1.605s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [1.606s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [1.607s] [ext: omni.kit.viewport.window-106.0.8] startup
# [1.619s] [ext: omni.kit.window.property-1.11.1] startup
# [1.621s] [ext: omni.usdphysics-106.0.20] startup
# [1.623s] [ext: omni.graph.tools-1.78.0] startup
# [1.634s] [ext: omni.kit.viewport.utility-1.0.17] startup
# [1.634s] [ext: omni.kit.property.usd-3.21.28] startup
# [1.639s] [ext: omni.graph-1.135.0] startup
# [1.740s] [ext: omni.graph.image.core-0.3.2] startup
# [1.743s] [ext: omni.graph.ui-1.70.0] startup
# [1.752s] [ext: omni.graph.action_core-1.1.4] startup
# [1.757s] [ext: omni.kit.window.cursor-1.1.2] startup
# [1.758s] [ext: omni.graph.image.nodes-1.0.2] startup
# [1.760s] [ext: omni.graph.action_nodes-1.23.0] startup
# [1.766s] [ext: omni.kit.viewport.menubar.core-106.0.2] startup
# [1.781s] [ext: omni.graph.nodes-1.143.0] startup
# [1.791s] [ext: omni.graph.action-1.102.1] startup
# [1.795s] [ext: omni.warp.core-1.2.1] startup
# [1.867s] [ext: omni.syntheticdata-0.6.7] startup
# [1.904s] [ext: omni.warp-1.2.1] startup
# [1.916s] [ext: omni.kvdb-106.0.20] startup
# [1.924s] [ext: omni.physx.foundation-106.0.20] startup
# [1.926s] [ext: omni.localcache-106.0.20] startup
# [1.931s] [ext: omni.convexdecomposition-106.0.20] startup
# [1.935s] [ext: omni.sensors.tiled-0.0.4] startup
# [1.938s] [ext: omni.physx.cooking-106.0.20] startup
# [1.950s] [ext: omni.kit.viewport.actions-106.0.3] startup
# [1.964s] [ext: omni.debugdraw-0.1.3] startup
# [1.972s] [ext: omni.physx-106.0.20] startup
# [2.008s] [ext: omni.kit.viewport.menubar.display-106.0.2] startup
# [2.077s] [ext: omni.kit.manipulator.transform-104.7.5] startup
# [2.085s] [ext: omni.kit.widget.toolbar-1.6.2] startup
# [2.111s] [ext: omni.physx.stageupdate-106.0.20] startup
# [2.113s] [ext: omni.usdphysics.ui-106.0.20] startup
# [2.129s] [ext: omni.physx.commands-106.0.20] startup
# [2.133s] [ext: omni.kit.manipulator.tool.snap-1.4.5] startup
# [2.136s] [ext: omni.kit.property.material-1.9.4] startup
# [2.138s] [ext: omni.physx.ui-106.0.20] startup
# [2.157s] [ext: omni.kit.manipulator.selector-1.1.1] startup
# [2.159s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [2.160s] [ext: omni.kit.manipulator.viewport-107.0.0] startup
# [2.161s] [ext: omni.kit.property.physx-106.0.20] startup
# [2.209s] [ext: omni.physx.demos-106.0.20] startup
# [2.221s] [ext: omni.kit.viewport.manipulator.transform-106.0.1] startup
# [2.223s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [2.224s] [ext: omni.ui_query-1.1.2] startup
# [2.225s] [ext: omni.fabric.commands-1.1.4] startup
# [2.229s] [ext: omni.physx.vehicle-106.0.20] startup
# [2.240s] [ext: omni.kit.manipulator.prim.core-107.0.3] startup
# [2.246s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [2.248s] [ext: omni.kit.ui_test-1.2.18] startup
# [2.250s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [2.250s] [ext: omni.physx.camera-106.0.20] startup
# [2.257s] [ext: omni.kit.manipulator.prim.fabric-106.0.1] startup
# [2.260s] [ext: omni.kit.manipulator.prim.usd-106.0.1] startup
# [2.261s] [ext: omni.physx.cct-106.0.20] startup
# [2.268s] [ext: omni.physics.tensors-106.0.20] startup
# [2.274s] [ext: omni.isaac.version-1.1.0] startup
# [2.276s] [ext: omni.kit.manipulator.selection-104.0.9] startup
# [2.278s] [ext: omni.kit.manipulator.prim-106.0.0] startup
# [2.278s] [ext: omni.command.usd-1.0.3] startup
# [2.279s] [ext: omni.physx.tensors-106.0.20] startup
# [2.283s] [ext: omni.isaac.nucleus-0.3.0] startup
# [2.283s] [ext: omni.kit.window.toolbar-1.6.1] startup
# [2.285s] [ext: omni.kit.widget.layers-1.7.9] startup
# [2.292s] [ext: omni.physx.graph-106.0.20] startup
# [2.302s] [ext: omni.physx.supportui-106.0.20] startup
# [2.321s] [ext: omni.physx.telemetry-106.0.20] startup
# [2.324s] [ext: omni.graph.scriptnode-1.19.1] startup
# [2.326s] [ext: omni.graph.ui_nodes-1.25.1] startup
# [2.330s] [ext: omni.kit.numpy.common-0.1.2] startup
# [2.333s] [ext: omni.physx.bundle-106.0.20] startup
# [2.334s] [ext: omni.kit.window.material_graph-1.8.15] startup
# [2.376s] [ext: omni.graph.bundle.actWarp 1.2.1 initialized:
#    CUDA Toolkit 11.8, Driver 12.4
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA GeForce RTX 4060 Ti" (16 GiB, sm_89, mempool enabled)
#    Kernel cache:
#      /home/bigcowfish/.cache/warp/1.2.1
# ion-2.0.4] startup
# [2.378s] [ext: omni.isaac.dynamic_control-1.3.8] startup
# [2.386s] [ext: omni.replicator.core-1.11.14] startup
# 2024-10-30 10:08:41 [2,435ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registered, overwriting annotator template
# [2.529s] [ext: omni.isaac.core-3.18.1] startup
# [3.310s] [ext: omni.graph.visualization.nodes-2.1.1] startup
# [3.317s] [ext: omni.isaac.core_nodes-1.16.1] startup
# [3.326s] [ext: omni.isaac.cloner-0.8.1] startup
# [3.330s] [ext: omni.isaac.ui-0.16.0] startup
# [3.337s] [ext: omni.kit.graph.widget.variables-2.1.0] startup
# [3.339s] [ext: omni.kit.graph.delegate.modern-1.10.6] startup
# [3.344s] [ext: omni.isaac.wheeled_robots-2.3.3] startup
# [3.357s] [ext: omni.isaac.gym-0.11.3] startup
# [3.361s] [ext: omni.graph.window.core-1.109.0] startup
# [3.373s] [ext: omni.isaac.debug_draw-1.1.0] startup
# [3.378s] [ext: omni.isaac.block_world-1.0.0] startup
# [3.382s] [ext: omni.graph.window.generic-1.24.0] startup
# [3.395s] [ext: omni.isaac.menu-0.5.0] startup
# [3.401s] [ext: omni.isaac.occupancy_map-1.0.2] startup
# [3.414s] [ext: omni.importer.mjcf-1.1.1] startup
# [3.422s] [ext: omni.graph.window.action-1.26.0] startup
# [3.429s] [ext: omni.kit.widget.live-2.1.6] startup
# [3.431s] [ext: omni.kit.actions.window-1.1.1] startup
# [3.434s] [ext: omni.kit.ui.actions-1.0.1] startup
# [3.435s] [ext: omni.kit.widget.cache_indicator-2.0.8] startup
# [3.465s] [ext: omni.kit.hotkeys.window-1.4.5] startup
# [3.469s] [ext: omni.kit.selection-0.1.4] startup
# [3.470s] [ext: omni.kit.menu.common-1.1.5] startup
# [3.471s] [ext: omni.sensors.nv.common-1.2.2-isaac] startup
# [3.479s] [ext: omni.isaac.kit-1.13.0] startup
# [3.480s] [ext: omni.kit.menu.edit-1.1.24] startup
# [3.483s] [ext: omni.kit.menu.file-1.1.10] startup
# [3.485s] [ext: omni.isaac.range_sensor-3.1.1] startup
# [3.495s] [ext: omni.sensors.nv.materials-1.2.1-isaac] startup
# [3.496s] [ext: omni.kit.property.audio-1.0.11] startup
# [3.498s] [ext: omni.kit.widget.stage_icons-1.0.4] startup
# [3.501s] [ext: omni.kit.property.geometry-1.3.0] startup
# [3.503s] [ext: omni.kit.property.camera-1.0.6] startup
# [3.504s] [ext: omni.sensors.nv.lidar-1.2.2-isaac] startup
# [3.508s] [ext: omni.sensors.nv.wpm-1.2.1-isaac] startup
# [3.508s] [ext: omni.hydra.scene_api-0.1.2] startup
# [3.514s] [ext: omni.kit.window.stage-2.5.10] startup
# [3.517s] [ext: omni.kit.property.render-1.1.1] startup
# [3.518s] [ext: omni.kit.property.light-1.0.8] startup
# [3.519s] [ext: omni.sensors.nv.radar-1.2.1-isaac] startup
# [3.523s] [ext: omni.kit.property.transform-1.5.1] startup
# [3.526s] [ext: omni.kit.menu.stage-1.2.5] startup
# [3.527s] [ext: omni.kit.profiler.window-2.2.1] startup
# 2024-10-30 10:08:42 [3,523ms] [Warning] [omni.kit.profiler.window] remove _SpanInstance.__lt__ and use insort 'key' arg instead
# [3.532s] [ext: omni.kit.property.bundle-1.2.11] startup
# [3.534s] [ext: omni.kit.property.isaac-0.2.3] startup
# [3.536s] [ext: omni.isaac.sensor-12.7.1] startup
# [3.585s] [ext: omni.isaac.surface_gripper-1.0.1] startup
# [3.588s] [ext: omni.kit.stage_column.payload-2.0.0] startup
# [3.591s] [ext: omni.kit.property.layer-1.1.6] startup
# [3.597s] [ext: omni.isaac.scene_blox-0.1.2] startup
# [3.601s] [ext: omni.isaac.quadruped-1.4.5] startup
# [3.622s] [ext: omni.isaac.manipulators-2.1.0] startup
# [3.629s] [ext: omni.isaac.lula-3.0.1] startup
# [3.636s] [ext: omni.kit.viewport.menubar.render-106.1.3] startup
# [3.643s] [ext: omni.kit.viewport.menubar.settings-106.0.1] startup
# [3.646s] [ext: omni.kit.viewport.menubar.camera-105.1.8] startup
# [3.649s] [ext: omni.kit.manipulator.camera-105.0.5] startup
# [3.651s] [ext: omni.isaac.motion_generation-7.1.0] startup
# [3.654s] [ext: omni.kit.widget.calendar-1.0.8] startup
# [3.656s] [ext: omni.kit.stage_column.variant-1.0.13] startup
# [3.657s] [ext: omni.kit.viewport.bundle-104.0.1] startup
# [3.657s] [ext: omni.isaac.universal_robots-0.3.5] startup
# [3.658s] [ext: omni.kit.widget.extended_searchfield-1.0.28] startup
# [3.665s] [ext: omni.kit.widget.timeline-105.0.1] startup
# [3.669s] [ext: omni.kit.window.commands-0.2.5] startup
# [3.670s] [ext: omni.kit.window.console-0.2.12Saving a temp livesync stage at  omniverse://localhost/Users/yudaniel888/temp_jupyter_stage.usd  ...Done.
# ] startup
# [3.678s] [ext: omni.kit.window.script_editor-1.7.6] startup
# [3.680s] [ext: omni.kit.menu.create-1.0.13] startup
# [3.681s] [ext: omni.kit.window.status_bar-0.1.6] startup
# [3.685s] [ext: omni.rtx.window.settings-0.6.16] startup
# [3.688s] [ext: omni.isaac.franka-0.4.1] startup
# [3.689s] [ext: omni.kit.window.title-1.1.3] startup
# [3.691s] [ext: omni.replicator.isaac-1.15.0] startup
# [3.701s] [ext: omni.replicator.replicator_yaml-2.0.5] startup
# [3.722s] [ext: omni.rtx.settings.core-0.6.0] startup
# [3.726s] [ext: omni.isaac.cortex-0.3.8] startup
# [3.729s] [ext: omni.kit.viewport.menubar.lighting-106.0.2] startup
# [3.737s] [ext: semantics.schema.editor-0.3.6] startup
# [3.741s] [ext: semantics.schema.property-1.0.3] startup
# [3.742s] [ext: omni.kit.viewport.rtx-104.0.1] startup
# [3.742s] [ext: omni.isaac.utils-1.0.1] startup
# [3.744s] [ext: omni.isaac.cortex.sample_behaviors-1.0.5] startup
# [3.746s] [ext: omni.importer.urdf-1.14.1] startup
# [3.777s] [ext: omni.kit.window.stats-0.1.6] startup
# [3.782s] [ext: omni.isaac.sim.python-4.1.0] startup
# [3.783s] Simulation App Starting
# [6.934s] app ready
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.local/share/ov/pkg/isaac-sim-4.1.0/kit/exts/omni.kit.widget.live/omni/kit/widget/live/live_state_menu.py:77, in LiveStateDelegate._on_layer_event(self, event)
#      74 if not payload.is_layer_influenced(self._usd_context.get_stage_url()):
#      75     return
# ---> 77 self.__update_live_tooltip()
#
# File ~/.local/share/ov/pkg/isaac-sim-4.1.0/kit/exts/omni.kit.widget.live/omni/kit/widget/live/live_state_menu.py:168, in LiveStateDelegate.__update_live_tooltip(self)
#     166 peer_users_count = len(current_session.peer_users)
#     167 if peer_users_count > 0:
# --> 168     self._live_background.set_tooltip(
#     169         f"Leave Session {current_session.name}\n{peer_users_count + 1} Total Users in Session"
#     170     )
#     171 else:
#     172     self._live_background.set_tooltip(
#     173         f"Leave Session {current_session.name}"
#     174     )
#
# AttributeError: 'NoneType' object has no attribute 'set_tooltip'

# %%
from omni.isaac.core import World
from omni.isaac.core.objects import DynamicCuboid
import numpy as np

# %%
world = World(stage_units_in_meters=1.0)
world.scene.add_default_ground_plane()
# A render/ step or an update call is needed to reflect the changes to the opened USD in Isaac Sim GUI
#  Note: avoid pressing play/ pause or stop in the GUI in this workflow.
world.render()

# %%
fancy_cube = world.scene.add(
    DynamicCuboid(
        prim_path="/World/random_cube",
        name="fancy_cube",
        position=np.array([0, 0, 1.000]),
        scale=np.array([0.5015, 0.505, 0.5015]),
        size=1.0,
        color=np.array([0, 0, 1.0]),
    )
)
world.render()

# %%
world.reset()
for i in range(500):
    position, orientation = fancy_cube.get_world_pose()
    linear_velocity = fancy_cube.get_linear_velocity()
    print("Cube position is : " + str(position))
    print("Cube's orientation is : " + str(orientation))
    print("Cube's linear velocity is : " + str(linear_velocity))
    # we have control over stepping physics and rendering in this workflow
    # things run in sync
    world.step(render=True)  # execute one physics step and one rendering step
# Out:
# Cube position is : [0.       0.       0.991825]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.          0.         -0.32700002]
# Cube position is : [0.         0.         0.98364997]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.          0.         -0.49050003]
# Cube position is : [0.         0.         0.97274995]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.          0.         -0.65400004]
# Cube position is : [0.        0.        0.9591249]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.          0.         -0.81750005]
# Cube position is : [0.        0.        0.9427749]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.          0.         -0.98100007]
# Cube position is : [0.        0.        0.9236999]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.      0.     -1.1445]
# Cube position is : [0.         0.         0.90189993]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.         0.        -1.3080001]
# Cube position is : [0.         0.         0.87737495]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.         0.        -1.4715002]
# Cube position is : [0.         0.         0.85012496]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.         0.        -1.6350002]
# Cube position is : [0.         0.         0.82014996]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.         0.        -1.7985003]
# Cube position is : [0.         0.         0.78744996]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.         0.        -1.9620004]
# Cube position is : [0.         0.         0.75202495]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.         0.        -2.1255004]
# Cube position is : [0.         0.         0.71387494]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.         0.        -2.2890005]
# Cube position is : [0.        0.        0.6729999]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.         0.        -2.4525006]
# Cube position is : [0.        0.        0.6293999]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.         0.        -2.6160007]
# Cube position is : [0.         0.         0.58307487]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.         0.        -2.7795007]
# Cube position is : [0.         0.         0.53402483]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.         0.        -2.9430008]
# Cube position is : [0.         0.         0.48224983]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.         0.        -3.1065009]
# Cube position is : [0.        0.        0.4277498]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.        0.       -3.270001]
# Cube position is : [0.        0.        0.3705248]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.        0.       -3.433501]
# Cube position is : [0.         0.         0.31057492]
# Cube's orientation is : [1. 0. 0. 0.]
# Cube's linear velocity is : [ 0.        0.       -3.597001]
# Cube position is : [3.3147546e-10 0.0000000e+00 2.5068054e-01]
# Cube's orientation is : [ 9.9999934e-01  7.1980822e-04  8.6343492e-04 -8.5807805e-11]
# Cube's linear velocity is : [ 4.3802055e-07  0.0000000e+00 -8.6117655e-02]
# Cube position is : [-0.00040007  0.00032748  0.25075483]
# Cube's orientation is : [1.0000000e+00 1.9257253e-05 1.9479008e-05 6.5233742e-08]
# Cube's linear velocity is : [ 0.01470891 -0.00204361 -0.00506429]
# Cube position is : [-0.00043007  0.00035904  0.25075012]
# Cube's orientation is : [1.0000000e+00 1.3507854e-06 2.2245656e-06 2.7395021e-07]
# Cube's linear velocity is : [ 0.00075957 -0.00142802 -0.00038825]
# Cube position is : [-0.00043333  0.00036098  0.2507501 ]
# Cube's orientation is : [ 1.0000000e+00  1.7456020e-07 -1.7024838e-07  1.4767689e-07]
# Cube's linear velocity is : [ 6.3150504e-04 -5.1818858e-04 -5.2915464e-05]
# Cube position is : [-0.00043279  0.00036088  0.25075004]
# Cube's orientation is : [1.0000000e+00 1.0673623e-07 1.9390856e-07 1.1381376e-07]
# Cube's linear velocity is : [ 3.4913392e-04 -3.8279512e-04 -1.3797882e-05]
# Cube position is : [-0.00043323  0.00036111  0.25075   ]
# Cube's orientation is : [ 1.0000000e+00  1.0390671e-08 -4.0366832e-08  1.2272838e-07]
# Cube's linear velocity is : [ 5.3569273e-04 -4.3093160e-04 -2.3239407e-05]
# Cube position is : [-0.00043347  0.00036232  0.25074986]
# Cube's orientation is : [ 1.0000000e+00 -1.1769047e-06 -1.4632700e-07  8.4751996e-08]
# Cube's linear velocity is : [ 0.00047529 -0.0006411  -0.00015482]
# Cube position is : [-0.00043327  0.00036246  0.25074956]
# Cube's orientation is : [ 1.0000000e+00 -1.2555606e-06  7.4476802e-08  5.5812794e-08]
# Cube's linear velocity is : [ 3.8905305e-04 -6.9088605e-04 -9.4878509e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2422385e-06  3.6787526e-08  5.5547304e-08]
# Cube's linear velocity is : [ 3.8081029e-04 -6.9434865e-04 -9.4080948e-05]
# Cube position is : [-0.00043324  0.00036247  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2579164e-06  8.4687741e-08  5.5497512e-08]
# Cube's linear velocity is : [ 3.8131472e-04 -6.9380918e-04 -9.4016919e-05]
# Cube position is : [-0.00043328  0.00036246  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2453507e-06  4.7785875e-08  5.5027829e-08]
# Cube's linear velocity is : [ 3.8024766e-04 -6.9534837e-04 -9.4075825e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2321875e-06  8.6435810e-09  5.4832491e-08]
# Cube's linear velocity is : [ 3.8056527e-04 -6.9492584e-04 -9.4000854e-05]
# Cube position is : [-0.00043327  0.00036247  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2476839e-06  5.8074846e-08  5.4624330e-08]
# Cube's linear velocity is : [ 3.8115101e-04 -6.9425756e-04 -9.3946488e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2347821e-06  1.9871109e-08  5.4323870e-08]
# Cube's linear velocity is : [ 3.8032880e-04 -6.9461134e-04 -9.4111449e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2507992e-06  6.9115899e-08  5.4093181e-08]
# Cube's linear velocity is : [ 3.8119673e-04 -6.9461565e-04 -9.3970353e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2376906e-06  3.1015134e-08  5.3798956e-08]
# Cube's linear velocity is : [ 3.8029786e-04 -6.9444586e-04 -9.4109702e-05]
# Cube position is : [-0.00043325  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2536980e-06  7.9446686e-08  6.8453645e-08]
# Cube's linear velocity is : [ 3.8124749e-04 -6.9424376e-04 -9.4015057e-05]
# Cube position is : [-0.00043327  0.00036246  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2407055e-06  4.1286651e-08  5.3360772e-08]
# Cube's linear velocity is : [ 3.8035167e-04 -6.9465919e-04 -9.4090727e-05]
# Cube position is : [-0.00043324  0.00036247  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2561973e-06  8.9961532e-08  5.3235464e-08]
# Cube's linear velocity is : [ 3.8117837e-04 -6.9389713e-04 -9.3987350e-05]
# Cube position is : [-0.00043326  0.00036245  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2436295e-06  5.2281163e-08  6.7645040e-08]
# Cube's linear velocity is : [ 3.8029451e-04 -6.9501722e-04 -9.4115756e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2303947e-06  1.3918220e-08  6.7367786e-08]
# Cube's linear velocity is : [ 3.8050994e-04 -6.9523731e-04 -9.3952542e-05]
# Cube position is : [-0.00043327  0.00036245  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2468633e-06  6.3411164e-08  5.2273496e-08]
# Cube's linear velocity is : [ 3.8097592e-04 -6.9412624e-04 -9.4130890e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2333051e-06  2.5078009e-08  5.2023573e-08]
# Cube's linear velocity is : [ 3.8051457e-04 -6.9494545e-04 -9.3947070e-05]
# Cube position is : [-0.00043325  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2493555e-06  7.3475270e-08  6.6679462e-08]
# Cube's linear velocity is : [ 3.8128044e-04 -6.9428957e-04 -9.4014475e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2364660e-06  3.6013198e-08  6.6296110e-08]
# Cube's linear velocity is : [ 3.8028311e-04 -6.9493585e-04 -9.4076524e-05]
# Cube position is : [-0.00043326  0.00036247  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2515603e-06  8.4999940e-08  5.1372218e-08]
# Cube's linear velocity is : [ 3.8115541e-04 -6.9384323e-04 -9.3932518e-05]
# Cube position is : [-0.00043327  0.00036245  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2395706e-06  4.6251269e-08  6.5854195e-08]
# Cube's linear velocity is : [ 3.8042117e-04 -6.9503108e-04 -9.4193172e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2255531e-06  8.2074605e-09  6.5605192e-08]
# Cube's linear velocity is : [ 3.8040293e-04 -6.9465337e-04 -9.3925184e-05]
# Cube position is : [-0.00043327  0.00036245  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2421715e-06  5.7616248e-08  5.0505740e-08]
# Cube's linear velocity is : [ 3.8100206e-04 -6.9428317e-04 -9.4131356e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2286450e-06  1.9273486e-08  5.0255579e-08]
# Cube's linear velocity is : [ 3.8051992e-04 -6.9495564e-04 -9.3949282e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2446699e-06  6.8496362e-08  5.0026909e-08]
# Cube's linear velocity is : [ 3.8122645e-04 -6.9465430e-04 -9.3968723e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2315785e-06  3.0379212e-08  4.9732957e-08]
# Cube's linear velocity is : [ 3.802998e-04 -6.944467e-04 -9.411075e-05]
# Cube position is : [-0.00043325  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2475901e-06  7.8810324e-08  6.4387777e-08]
# Cube's linear velocity is : [ 3.8124691e-04 -6.9424463e-04 -9.4016686e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2346825e-06  4.1360018e-08  6.4004155e-08]
# Cube's linear velocity is : [ 3.8028197e-04 -6.9493667e-04 -9.4070820e-05]
# Cube position is : [-0.00043324  0.00036247  0.2507497 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2498161e-06  8.9522935e-08  6.3964528e-08]
# Cube's linear velocity is : [ 3.812084e-04 -6.934811e-04 -9.398584e-05]
# Cube position is : [-0.00043327  0.00036246  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2376430e-06  5.1676206e-08  4.8770996e-08]
# Cube's linear velocity is : [ 3.8038418e-04 -6.9542316e-04 -9.4114825e-05]
# Cube position is : [-0.00043328  0.00036248  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2810965e-06  1.3380754e-08  4.8555034e-08]
# Cube's linear velocity is : [ 3.8072761e-04 -6.9487956e-04 -9.3622621e-05]
# Cube position is : [-0.00043327  0.00036246  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2399246e-06  6.3175456e-08  6.3066743e-08]
# Cube's linear velocity is : [ 3.8069885e-04 -6.9398206e-04 -9.4390380e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2268704e-06  2.4598940e-08  6.2805874e-08]
# Cube's linear velocity is : [ 3.8049096e-04 -6.9500908e-04 -9.4019248e-05]
# Cube position is : [-0.00043327  0.00036247  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2423707e-06  7.4063514e-08  6.2592719e-08]
# Cube's linear velocity is : [ 3.8114513e-04 -6.9427781e-04 -9.3941133e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2294638e-06  3.5853454e-08  6.2292230e-08]
# Cube's linear velocity is : [ 3.8032784e-04 -6.9461507e-04 -9.4111565e-05]
# Cube position is : [-0.00043324  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2454192e-06  8.3565673e-08  6.2236083e-08]
# Cube's linear velocity is : [ 3.8132185e-04 -6.9397670e-04 -9.4034265e-05]
# Cube position is : [-0.00043328  0.00036245  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2323259e-06  4.6898542e-08  6.1782238e-08]
# Cube's linear velocity is : [ 3.8017408e-04 -6.9498690e-04 -9.4046256e-05]
# Cube position is : [-0.00043328  0.00036248  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2760872e-06  7.7568343e-09  6.1631411e-08]
# Cube's linear velocity is : [ 3.8085715e-04 -6.9497805e-04 -9.3643692e-05]
# Cube position is : [-0.00043327  0.00036246  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2353919e-06  5.7263446e-08  4.6508809e-08]
# Cube's linear velocity is : [ 3.807245e-04 -6.940614e-04 -9.445464e-05]
# Cube position is : [-0.00043328  0.00036248  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2786820e-06  1.9009589e-08  4.6302624e-08]
# Cube's linear velocity is : [ 3.8073285e-04 -6.9478533e-04 -9.3610281e-05]
# Cube position is : [-0.00043326  0.00036246  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2375049e-06  6.7982803e-08  7.5700342e-08]
# Cube's linear velocity is : [ 3.8075374e-04 -6.9361372e-04 -9.4436247e-05]
# Cube position is : [-0.00043328  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2826351e-06  3.0016125e-08  6.0514289e-08]
# Cube's linear velocity is : [ 3.805974e-04 -6.953825e-04 -9.382926e-05]
# Cube position is : [-0.00043325  0.00036246  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2404389e-06  7.9155491e-08  3.0743621e-08]
# Cube's linear velocity is : [ 3.8086393e-04 -6.9364422e-04 -9.4258714e-05]
# Cube position is : [-0.00043327  0.00036244  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2280880e-06  4.0653575e-08  6.0039994e-08]
# Cube's linear velocity is : [ 3.8035787e-04 -6.9488247e-04 -9.4159062e-05]
# Cube position is : [-0.00043324  0.00036247  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2421235e-06  8.9571785e-08  5.9991599e-08]
# Cube's linear velocity is : [ 3.8127744e-04 -6.9371087e-04 -9.3774077e-05]
# Cube position is : [-0.00043327  0.00036246  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2293253e-06  5.2044275e-08  4.4811099e-08]
# Cube's linear velocity is : [ 3.8032798e-04 -6.9512444e-04 -9.4064999e-05]
# Cube position is : [-0.00043328  0.00036248  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2732694e-06  1.3520539e-08  4.4580130e-08]
# Cube's linear velocity is : [ 3.8079722e-04 -6.9523667e-04 -9.3645671e-05]
# Cube position is : [-0.00043327  0.00036246  0.25074962]
# Cube's orientation is : [ 1.000000e+00 -1.232456e-06  6.314892e-08  5.908305e-08]
# Cube's linear velocity is : [ 3.8074268e-04 -6.9417816e-04 -9.4415642e-05]
# Cube position is : [-0.00043328  0.00036248  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2759056e-06  2.4771568e-08  5.8879671e-08]
# Cube's linear velocity is : [ 3.807200e-04 -6.947177e-04 -9.364171e-05]
# Cube position is : [-0.00043327  0.00036246  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2351412e-06  7.4342957e-08  4.3753118e-08]
# Cube's linear velocity is : [ 3.8070974e-04 -6.9406652e-04 -9.4445328e-05]
# Cube position is : [-0.00043327  0.00036248  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2787357e-06  3.5139614e-08  5.8422707e-08]
# Cube's linear velocity is : [ 3.8082563e-04 -6.9460843e-04 -9.3673611e-05]
# Cube position is : [-0.00043324  0.00036246  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2378759e-06  8.3953410e-08  4.3388354e-08]
# Cube's linear velocity is : [ 3.8078867e-04 -6.9375284e-04 -9.4466632e-05]
# Cube position is : [-0.00043326  0.00036248  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2815087e-06  4.6229459e-08  5.7891654e-08]
# Cube's linear velocity is : [ 3.807039e-04 -6.952001e-04 -9.361121e-05]
# Cube position is : [-0.00043328  0.00036248  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2678336e-06  8.0187297e-09  5.7633365e-08]
# Cube's linear velocity is : [ 3.8054169e-04 -6.9512893e-04 -9.3902134e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2856469e-06  5.7363820e-08  5.7276537e-08]
# Cube's linear velocity is : [ 3.808996e-04 -6.943949e-04 -9.431692e-05]
# Cube position is : [-0.00043328  0.00036248  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2708301e-06  1.9147620e-08  5.7103620e-08]
# Cube's linear velocity is : [ 3.8058276e-04 -6.9467461e-04 -9.3779083e-05]
# Cube position is : [-0.00043327  0.00036244  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2309288e-06  6.8826921e-08  5.6725110e-08]
# Cube's linear velocity is : [ 3.8053235e-04 -6.9394836e-04 -9.4606563e-05]
# Cube position is : [-0.00043328  0.00036248  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2737221e-06  3.0325925e-08  5.6572826e-08]
# Cube's linear velocity is : [ 3.8090121e-04 -6.9504126e-04 -9.3475588e-05]
# Cube position is : [-0.00043325  0.00036244  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2338094e-06  7.9151640e-08  7.1084834e-08]
# Cube's linear velocity is : [ 3.8063666e-04 -6.9364259e-04 -9.4645446e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2776916e-06  4.0610406e-08  4.1254310e-08]
# Cube's linear velocity is : [ 3.8078421e-04 -6.9508178e-04 -9.3655333e-05]
# Cube position is : [-0.00043325  0.00036246  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2354719e-06  9.0392440e-08  7.0634599e-08]
# Cube's linear velocity is : [ 3.8082426e-04 -6.9389865e-04 -9.4222392e-05]
# Cube position is : [-0.00043327  0.00036248  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2792304e-06  5.1905957e-08  5.5622632e-08]
# Cube's linear velocity is : [ 3.8082825e-04 -6.9517415e-04 -9.3623901e-05]
# Cube position is : [-0.00043328  0.00036248  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2651799e-06  1.3777110e-08  5.5389052e-08]
# Cube's linear velocity is : [ 3.8045881e-04 -6.9465535e-04 -9.3912378e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2829007e-06  6.3147496e-08  5.5034604e-08]
# Cube's linear velocity is : [ 3.8088817e-04 -6.9436582e-04 -9.4304000e-05]
# Cube position is : [-0.00043328  0.00036248  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2680866e-06  2.4925981e-08  5.4861857e-08]
# Cube's linear velocity is : [ 3.8058174e-04 -6.9467106e-04 -9.3782692e-05]
# Cube position is : [-0.00043327  0.00036247  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2852057e-06  7.4558784e-08  5.4527217e-08]
# Cube's linear velocity is : [ 3.8083165e-04 -6.9401355e-04 -9.4265000e-05]
# Cube position is : [-0.00043328  0.00036248  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2711466e-06  3.5981060e-08  5.4332688e-08]
# Cube's linear velocity is : [ 3.8068803e-04 -6.9520529e-04 -9.3818431e-05]
# Cube position is : [-0.00043324  0.00036244  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2313244e-06  8.4085173e-08  5.4126026e-08]
# Cube's linear velocity is : [ 3.806679e-04 -6.933325e-04 -9.469294e-05]
# Cube position is : [-0.00043328  0.00036248  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2741391e-06  4.7015849e-08  5.3814524e-08]
# Cube's linear velocity is : [ 3.8077938e-04 -6.9558364e-04 -9.3425297e-05]
# Cube position is : [-0.00043328  0.00036246  0.2507497 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2622706e-06  8.1323206e-09  5.3513613e-08]
# Cube's linear velocity is : [ 3.8028334e-04 -6.9455738e-04 -9.4285373e-05]
# Cube position is : [-0.00043327  0.00036247  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2783592e-06  5.7319088e-08  5.3284946e-08]
# Cube's linear velocity is : [ 3.8118247e-04 -6.9457019e-04 -9.3994568e-05]
# Cube position is : [-0.00043328  0.00036247  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2645817e-06  1.9065268e-08  6.7863290e-08]
# Cube's linear velocity is : [ 3.8051084e-04 -6.9480046e-04 -9.3937408e-05]
# Cube position is : [-0.00043327  0.00036247  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2809705e-06  6.8563182e-08  6.7589816e-08]
# Cube's linear velocity is : [ 3.8097432e-04 -6.9410470e-04 -9.4118201e-05]
# Cube position is : [-0.00043328  0.00036247  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2678420e-06  2.9988204e-08  5.2519081e-08]
# Cube's linear velocity is : [ 3.8053354e-04 -6.9504452e-04 -9.3999457e-05]
# Cube position is : [-0.00043325  0.00036247  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2838949e-06  7.8884504e-08  6.7132056e-08]
# Cube's linear velocity is : [ 3.8100837e-04 -6.9364172e-04 -9.4129260e-05]
# Cube position is : [-0.00043328  0.00036247  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2706416e-06  4.1114017e-08  5.1980010e-08]
# Cube's linear velocity is : [ 3.804785e-04 -6.953575e-04 -9.394241e-05]
# Cube position is : [-0.00043324  0.00036244  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2296131e-06  8.9403727e-08  5.1832878e-08]
# Cube's linear velocity is : [ 3.8078177e-04 -6.9334969e-04 -9.4487004e-05]
# Cube position is : [-0.00043326  0.00036248  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2723785e-06  5.1529028e-08  6.6408710e-08]
# Cube's linear velocity is : [ 3.8085412e-04 -6.9525000e-04 -9.3455215e-05]
# Cube position is : [-0.00043328  0.00036247  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2596147e-06  1.3320961e-08  5.1274103e-08]
# Cube's linear velocity is : [ 3.8038919e-04 -6.9496816e-04 -9.4078969e-05]
# Cube position is : [-0.00043327  0.00036247  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2762121e-06  6.2809455e-08  5.0983409e-08]
# Cube's linear velocity is : [ 3.8101149e-04 -6.9436495e-04 -9.4113893e-05]
# Cube position is : [-0.00043328  0.00036247  0.25074968]
# Cube's orientation is : [ 1.0000000e+00 -1.2627006e-06  2.4449623e-08  6.5550246e-08]
# Cube's linear velocity is : [ 3.8052356e-04 -6.9496315e-04 -9.3952658e-05]
# Cube position is : [-0.00043326  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2796258e-06  7.2962472e-08  5.0549716e-08]
# Cube's linear velocity is : [ 3.8111943e-04 -6.9419359e-04 -9.4180134e-05]
# Cube position is : [-0.00043328  0.00036247  0.25074962]
# Cube's orientation is : [ 1.0000000e+00 -1.2659669e-06  3.5360774e-08  6.5046216e-08]
# Cube's linear velocity is : [ 3.8041832e-04 -6.9501007e-04 -9.3933100e-05]
# Cube position is : [-0.00043326  0.00036247  0.25074965]
# Cube's orientation is : [ 1.0000000e+00 -1.2822928e-06  8.4194504e-08  5.0056816e-08]
# Cube's linear velocity is : [ 3.8103745e-04 -6.9385814e-04 -9.4140203e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8054123e-04 -6.9500244e-04 -9.3997478e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8035071e-04 -6.9495436e-04 -9.3894800e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033712e-04 -6.9494441e-04 -9.3890725e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803364e-04 -6.949426e-04 -9.389247e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033680e-04 -6.9494173e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033488e-04 -6.9494214e-04 -9.3895615e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803351e-04 -6.949422e-04 -9.389294e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494301e-04 -9.3895382e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033456e-04 -6.9494348e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033596e-04 -6.9494225e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033575e-04 -6.9494284e-04 -9.3889794e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033625e-04 -6.9494121e-04 -9.3890492e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803334e-04 -6.949414e-04 -9.389212e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033494e-04 -6.9494429e-04 -9.3894450e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033482e-04 -6.9494412e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494091e-04 -9.3890027e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033453e-04 -6.9494214e-04 -9.3890958e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033561e-04 -6.9494126e-04 -9.3888397e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803339e-04 -6.949438e-04 -9.389049e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033555e-04 -6.9494284e-04 -9.3892471e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033593e-04 -6.9494190e-04 -9.3886883e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033418e-04 -6.9494243e-04 -9.3895032e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033567e-04 -6.9494231e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494301e-04 -9.3895382e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033456e-04 -6.9494348e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033596e-04 -6.9494225e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033575e-04 -6.9494284e-04 -9.3889794e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033625e-04 -6.9494121e-04 -9.3890492e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803334e-04 -6.949414e-04 -9.389212e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033494e-04 -6.9494429e-04 -9.3894450e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033482e-04 -6.9494412e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494091e-04 -9.3890027e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033453e-04 -6.9494214e-04 -9.3890958e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033561e-04 -6.9494126e-04 -9.3888397e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803339e-04 -6.949438e-04 -9.389049e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033555e-04 -6.9494284e-04 -9.3892471e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033593e-04 -6.9494190e-04 -9.3886883e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033418e-04 -6.9494243e-04 -9.3895032e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033567e-04 -6.9494231e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494301e-04 -9.3895382e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033456e-04 -6.9494348e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033596e-04 -6.9494225e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033575e-04 -6.9494284e-04 -9.3889794e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033625e-04 -6.9494121e-04 -9.3890492e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803334e-04 -6.949414e-04 -9.389212e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033494e-04 -6.9494429e-04 -9.3894450e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033482e-04 -6.9494412e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494091e-04 -9.3890027e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033453e-04 -6.9494214e-04 -9.3890958e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033561e-04 -6.9494126e-04 -9.3888397e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803339e-04 -6.949438e-04 -9.389049e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033555e-04 -6.9494284e-04 -9.3892471e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033593e-04 -6.9494190e-04 -9.3886883e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033418e-04 -6.9494243e-04 -9.3895032e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033567e-04 -6.9494231e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494301e-04 -9.3895382e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033456e-04 -6.9494348e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033596e-04 -6.9494225e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033575e-04 -6.9494284e-04 -9.3889794e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033625e-04 -6.9494121e-04 -9.3890492e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803334e-04 -6.949414e-04 -9.389212e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033494e-04 -6.9494429e-04 -9.3894450e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033482e-04 -6.9494412e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494091e-04 -9.3890027e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033453e-04 -6.9494214e-04 -9.3890958e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033561e-04 -6.9494126e-04 -9.3888397e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803339e-04 -6.949438e-04 -9.389049e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033555e-04 -6.9494284e-04 -9.3892471e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033593e-04 -6.9494190e-04 -9.3886883e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033418e-04 -6.9494243e-04 -9.3895032e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033567e-04 -6.9494231e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494301e-04 -9.3895382e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033456e-04 -6.9494348e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033596e-04 -6.9494225e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033575e-04 -6.9494284e-04 -9.3889794e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033625e-04 -6.9494121e-04 -9.3890492e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803334e-04 -6.949414e-04 -9.389212e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033494e-04 -6.9494429e-04 -9.3894450e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033482e-04 -6.9494412e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494091e-04 -9.3890027e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033453e-04 -6.9494214e-04 -9.3890958e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033561e-04 -6.9494126e-04 -9.3888397e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803339e-04 -6.949438e-04 -9.389049e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033555e-04 -6.9494284e-04 -9.3892471e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033593e-04 -6.9494190e-04 -9.3886883e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033418e-04 -6.9494243e-04 -9.3895032e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033567e-04 -6.9494231e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494301e-04 -9.3895382e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033456e-04 -6.9494348e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033596e-04 -6.9494225e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033575e-04 -6.9494284e-04 -9.3889794e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033625e-04 -6.9494121e-04 -9.3890492e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803334e-04 -6.949414e-04 -9.389212e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033494e-04 -6.9494429e-04 -9.3894450e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033482e-04 -6.9494412e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494091e-04 -9.3890027e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033453e-04 -6.9494214e-04 -9.3890958e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033561e-04 -6.9494126e-04 -9.3888397e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803339e-04 -6.949438e-04 -9.389049e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033555e-04 -6.9494284e-04 -9.3892471e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033593e-04 -6.9494190e-04 -9.3886883e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033418e-04 -6.9494243e-04 -9.3895032e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033567e-04 -6.9494231e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494301e-04 -9.3895382e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033456e-04 -6.9494348e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033596e-04 -6.9494225e-04 -9.3892937e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033575e-04 -6.9494284e-04 -9.3889794e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033625e-04 -6.9494121e-04 -9.3890492e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803334e-04 -6.949414e-04 -9.389212e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033494e-04 -6.9494429e-04 -9.3894450e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033482e-04 -6.9494412e-04 -9.3891191e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033506e-04 -6.9494091e-04 -9.3890027e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033453e-04 -6.9494214e-04 -9.3890958e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.8033561e-04 -6.9494126e-04 -9.3888397e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# Cube's linear velocity is : [ 3.803339e-04 -6.949438e-04 -9.389049e-05]
# Cube position is : [-0.00043327  0.00036247  0.2507496 ]
# Cube's orientation is : [ 1.0000000e+00 -1.2691287e-06  4.5545999e-08  7.9423536e-08]
# ...
# Cube's linear velocity is : [ 3.8051928e-04 -6.9460593e-04 -9.5068070e-05]
# Cube position is : [-0.00635657  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2710890e-06  4.7712483e-08  1.9644419e-04]
# Cube's linear velocity is : [ 3.8092042e-04 -6.9524150e-04 -9.4552117e-05]
# Cube position is : [-0.00635657  0.00509924  0.24075459]
# Cube's orientation is : [ 1.0000000e+00 -1.2332738e-06  3.8522238e-08  1.9642482e-04]
# Cube's linear velocity is : [ 3.8072083e-04 -6.9484470e-04 -9.4873423e-05]
# Cube position is : [-0.00635654  0.00509925  0.24075453]
# Cube's orientation is : [ 1.0000000e+00 -1.2830577e-06  1.1670536e-07  1.9642053e-04]
# Cube's linear velocity is : [ 3.8153742e-04 -6.9425587e-04 -9.4764109e-05]
# Cube position is : [-0.00635654  0.00509923  0.24075456]
# Cube's orientation is : [ 1.0000000e+00 -1.2450538e-06  1.0737027e-07  1.9643077e-04]
# Cube's linear velocity is : [ 3.8070473e-04 -6.9444027e-04 -9.4898453e-05]
# Cube position is : [-0.00635656  0.00509925  0.24075456]
# Cube's orientation is : [ 1.0000000e+00 -1.2641808e-06  9.8953173e-08  1.9644106e-04]
# Cube's linear velocity is : [ 3.8092100e-04 -6.9517177e-04 -9.4484130e-05]
# Cube position is : [-0.00635656  0.00509926  0.24075456]
# Cube's orientation is : [ 1.0000000e+00 -1.2834633e-06  8.9617821e-08  1.9643662e-04]
# Cube's linear velocity is : [ 3.8100817e-04 -6.9484627e-04 -9.4544899e-05]
# Cube position is : [-0.00635656  0.00509924  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2465632e-06  8.0410317e-08  1.9643200e-04]
# Cube's linear velocity is : [ 3.8054324e-04 -6.9462036e-04 -9.5060619e-05]
# Cube position is : [-0.00635656  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2657645e-06  7.1084564e-08  1.9644237e-04]
# Cube's linear velocity is : [ 3.8096713e-04 -6.9478451e-04 -9.4536634e-05]
# Cube position is : [-0.00635657  0.00509926  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2849741e-06  6.2558406e-08  1.9642305e-04]
# Cube's linear velocity is : [ 3.8095107e-04 -6.9516030e-04 -9.4494375e-05]
# Cube position is : [-0.00635657  0.00509924  0.24075459]
# Cube's orientation is : [ 1.0000000e+00 -1.2481792e-06  5.3263435e-08  1.9643322e-04]
# Cube's linear velocity is : [ 3.8054126e-04 -6.9459819e-04 -9.5075520e-05]
# Cube position is : [-0.00635659  0.00509925  0.24075453]
# Cube's orientation is : [ 1.0000000e+00 -1.2679892e-06  4.4527621e-08  1.9644349e-04]
# Cube's linear velocity is : [ 3.8097272e-04 -6.9550646e-04 -9.4539078e-05]
# Cube position is : [-0.00635658  0.00509926  0.24075456]
# Cube's orientation is : [ 1.0000000e+00 -1.2870280e-06  3.5275043e-08  1.9643905e-04]
# Cube's linear velocity is : [ 3.8098803e-04 -6.9467368e-04 -9.4530697e-05]
# Cube position is : [-0.00635654  0.00509925  0.24075456]
# Cube's orientation is : [ 1.0000000e+00 -1.2789154e-06  1.1315760e-07  1.9643473e-04]
# Cube's linear velocity is : [ 3.8128172e-04 -6.9360842e-04 -9.5048163e-05]
# Cube position is : [-0.00635656  0.00509924  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2411782e-06  1.0452561e-07  1.9643009e-04]
# Cube's linear velocity is : [ 3.8063634e-04 -6.9489726e-04 -9.4886112e-05]
# Cube position is : [-0.00635656  0.00509923  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2613472e-06  9.5285053e-08  1.9642558e-04]
# Cube's linear velocity is : [ 3.8080502e-04 -6.9467659e-04 -9.4722433e-05]
# Cube position is : [-0.00635656  0.00509926  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2796249e-06  8.5860044e-08  1.9642120e-04]
# Cube's linear velocity is : [ 3.8116958e-04 -6.9493265e-04 -9.4354444e-05]
# Cube position is : [-0.00635656  0.00509924  0.24075459]
# Cube's orientation is : [ 1.0000000e+00 -1.2426228e-06  7.6614491e-08  1.9641657e-04]
# Cube's linear velocity is : [ 3.8058349e-04 -6.9464475e-04 -9.5037918e-05]
# Cube position is : [-0.00635656  0.00509925  0.24075453]
# Cube's orientation is : [ 1.0000000e+00 -1.2624056e-06  6.7062047e-08  1.9642693e-04]
# Cube's linear velocity is : [ 3.810431e-04 -6.951691e-04 -9.456923e-05]
# Cube position is : [-0.00635656  0.00509926  0.24075456]
# Cube's orientation is : [ 1.0000000e+00 -1.2815015e-06  5.7801508e-08  1.9642249e-04]
# Cube's linear velocity is : [ 3.8096914e-04 -6.9462648e-04 -9.4547460e-05]
# Cube position is : [-0.00635657  0.00509924  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2446070e-06  4.9310607e-08  1.9643258e-04]
# Cube's linear velocity is : [ 3.8048124e-04 -6.9489906e-04 -9.5030002e-05]
# Cube position is : [-0.00635658  0.00509923  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2647880e-06  4.0918223e-08  1.9642798e-04]
# Cube's linear velocity is : [ 3.8072458e-04 -6.9503125e-04 -9.4682036e-05]
# Cube position is : [-0.00635654  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2550620e-06  1.1865064e-07  1.9642377e-04]
# Cube's linear velocity is : [ 3.8157892e-04 -6.9387309e-04 -9.4730465e-05]
# Cube position is : [-0.00635654  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2751885e-06  1.0923322e-07  1.9644891e-04]
# Cube's linear velocity is : [ 3.8087138e-04 -6.9454079e-04 -9.4731397e-05]
# Cube position is : [-0.00635654  0.00509924  0.24075459]
# Cube's orientation is : [ 1.0000000e+00 -1.2372648e-06  1.0004076e-07  1.9642954e-04]
# Cube's linear velocity is : [ 3.8070822e-04 -6.9478061e-04 -9.4861316e-05]
# Cube position is : [-0.00635656  0.00509924  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2578988e-06  9.1324665e-08  1.9642494e-04]
# Cube's linear velocity is : [ 3.8076099e-04 -6.9509464e-04 -9.4744551e-05]
# Cube position is : [-0.00635656  0.00509926  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2763267e-06  8.1951285e-08  1.9642054e-04]
# Cube's linear velocity is : [ 3.8115022e-04 -6.9497834e-04 -9.4378658e-05]
# Cube position is : [-0.00635656  0.00509924  0.24075459]
# Cube's orientation is : [ 1.0000000e+00 -1.2393268e-06  7.2709071e-08  1.9641593e-04]
# Cube's linear velocity is : [ 3.8058314e-04 -6.9464749e-04 -9.5036987e-05]
# Cube position is : [-0.00635657  0.00509925  0.24075453]
# Cube's orientation is : [ 1.0000000e+00 -1.2592036e-06  6.3845299e-08  1.9644100e-04]
# Cube's linear velocity is : [ 3.8097316e-04 -6.9544680e-04 -9.4556308e-05]
# Cube position is : [-0.00635657  0.00509926  0.24075456]
# Cube's orientation is : [ 1.0000000e+00 -1.2781093e-06  5.4726407e-08  1.9642177e-04]
# Cube's linear velocity is : [ 3.8099775e-04 -6.9475273e-04 -9.4497518e-05]
# Cube position is : [-0.00635657  0.00509924  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2412493e-06  4.5373142e-08  1.9643194e-04]
# Cube's linear velocity is : [ 3.8054428e-04 -6.9454184e-04 -9.5076917e-05]
# Cube position is : [-0.00635658  0.00509923  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2614245e-06  3.6907114e-08  1.9642734e-04]
# Cube's linear velocity is : [ 3.8072318e-04 -6.9496001e-04 -9.4696705e-05]
# Cube position is : [-0.00635654  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2516393e-06  1.1468256e-07  1.9642313e-04]
# Cube's linear velocity is : [ 3.815822e-04 -6.938956e-04 -9.471591e-05]
# Cube position is : [-0.00635654  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2717123e-06  1.0531028e-07  1.9644827e-04]
# Cube's linear velocity is : [ 3.8087813e-04 -6.9457252e-04 -9.4715680e-05]
# Cube position is : [-0.00635654  0.00509924  0.24075459]
# Cube's orientation is : [ 1.0000000e+00 -1.2338496e-06  9.6155716e-08  1.9642890e-04]
# Cube's linear velocity is : [ 3.806961e-04 -6.947827e-04 -9.487086e-05]
# Cube position is : [-0.00635655  0.00509923  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2544605e-06  8.7461537e-08  1.9642430e-04]
# Cube's linear velocity is : [ 3.8076373e-04 -6.9510972e-04 -9.4737101e-05]
# Cube position is : [-0.00635656  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2736263e-06  7.8222534e-08  1.9643466e-04]
# Cube's linear velocity is : [ 3.8100415e-04 -6.9489825e-04 -9.4514515e-05]
# Cube position is : [-0.00635656  0.00509924  0.24075459]
# Cube's orientation is : [ 1.0000000e+00 -1.2358530e-06  6.8880027e-08  1.9643009e-04]
# Cube's linear velocity is : [ 3.8071687e-04 -6.9473317e-04 -9.4892050e-05]
# Cube position is : [-0.00635656  0.00509924  0.24075453]
# Cube's orientation is : [ 1.0000000e+00 -1.2566431e-06  5.9338131e-08  1.9642556e-04]
# Cube's linear velocity is : [ 3.8087572e-04 -6.9499895e-04 -9.4768999e-05]
# Cube position is : [-0.00635657  0.00509926  0.24075456]
# Cube's orientation is : [ 1.0000000e+00 -1.2749489e-06  5.0730090e-08  1.9643590e-04]
# Cube's linear velocity is : [ 3.8104353e-04 -6.9502939e-04 -9.4359450e-05]
# Cube position is : [-0.00635658  0.00509924  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2378346e-06  4.2346503e-08  1.9643120e-04]
# Cube's linear velocity is : [ 3.8053276e-04 -6.9503806e-04 -9.4972842e-05]
# Cube position is : [-0.00635659  0.00509923  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2581088e-06  3.3122873e-08  1.9642667e-04]
# Cube's linear velocity is : [ 3.8078046e-04 -6.9467811e-04 -9.4737799e-05]
# Cube position is : [-0.00635654  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2483263e-06  1.1077767e-07  1.9642246e-04]
# Cube's linear velocity is : [ 3.8158614e-04 -6.9381011e-04 -9.4729534e-05]
# Cube position is : [-0.00635656  0.00509925  0.24075457]
# Cube's orientation is : [ 1.00000000e+00 -1.26833913e-06  1.02197916e-07  1.96432724e-04]
# Cube's linear velocity is : [ 3.8082601e-04 -6.9490954e-04 -9.4666902e-05]
# Cube position is : [-0.00635656  0.00509926  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2876146e-06  9.2871971e-08  1.9642827e-04]
# Cube's linear velocity is : [ 3.8099044e-04 -6.9481856e-04 -9.4544666e-05]
# Cube position is : [-0.00635656  0.00509924  0.24075459]
# Cube's orientation is : [ 1.0000000e+00 -1.2507188e-06  8.3666755e-08  1.9642364e-04]
# Cube's linear velocity is : [ 3.8054216e-04 -6.9461827e-04 -9.5060735e-05]
# Cube position is : [-0.00635656  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2702036e-06  7.4173713e-08  1.9643402e-04]
# Cube's linear velocity is : [ 3.8100782e-04 -6.9495552e-04 -9.4555726e-05]
# Cube position is : [-0.00635656  0.00509924  0.24075459]
# Cube's orientation is : [ 1.0000000e+00 -1.2324881e-06  6.4851790e-08  1.9642945e-04]
# Cube's linear velocity is : [ 3.8070726e-04 -6.9473969e-04 -9.4904273e-05]
# Cube position is : [-0.00635656  0.00509924  0.24075453]
# Cube's orientation is : [ 1.0000000e+00 -1.2532432e-06  5.5325149e-08  1.9642492e-04]
# Cube's linear velocity is : [ 3.8087845e-04 -6.9501554e-04 -9.4761897e-05]
# Cube position is : [-0.00635657  0.00509925  0.24075456]
# Cube's orientation is : [ 1.0000000e+00 -1.2723214e-06  4.6855146e-08  1.9645001e-04]
# Cube's linear velocity is : [ 3.8089318e-04 -6.9494668e-04 -9.4503222e-05]
# Cube position is : [-0.00635657  0.00509924  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2344163e-06  3.7748457e-08  1.9643064e-04]
# Cube's linear velocity is : [ 3.8071585e-04 -6.9485785e-04 -9.4853167e-05]
# Cube position is : [-0.00635654  0.00509925  0.24075457]
# Cube's orientation is : [ 1.00000000e+00 -1.28363058e-06  1.16225756e-07  1.96426365e-04]
# Cube's linear velocity is : [ 3.8145986e-04 -6.9390365e-04 -9.4722200e-05]
# Cube position is : [-0.00635654  0.00509923  0.24075459]
# Cube's orientation is : [ 1.0000000e+00 -1.2458403e-06  1.0680685e-07  1.9643661e-04]
# Cube's linear velocity is : [ 3.8072819e-04 -6.9461454e-04 -9.4905670e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8094979e-04 -6.9527025e-04 -9.4535004e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.810309e-04 -6.949187e-04 -9.451102e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102767e-04 -6.9489097e-04 -9.4513933e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102517e-04 -6.9489010e-04 -9.4511721e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102540e-04 -6.9489080e-04 -9.4514515e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102706e-04 -6.9488911e-04 -9.4511604e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102642e-04 -6.9489022e-04 -9.4514515e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102610e-04 -6.9489056e-04 -9.4514631e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102685e-04 -6.9488998e-04 -9.4511604e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.810268e-04 -6.948890e-04 -9.451172e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102604e-04 -6.9488998e-04 -9.4514748e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102575e-04 -6.9489033e-04 -9.4514515e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102691e-04 -6.9488946e-04 -9.4511604e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102607e-04 -6.9489004e-04 -9.4514748e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102575e-04 -6.9489033e-04 -9.4514515e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102691e-04 -6.9488946e-04 -9.4511604e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102607e-04 -6.9489004e-04 -9.4514748e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102575e-04 -6.9489033e-04 -9.4514515e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102691e-04 -6.9488946e-04 -9.4511604e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102607e-04 -6.9489004e-04 -9.4514748e-05]
# Cube position is : [-0.00635655  0.00509925  0.24075457]
# Cube's orientation is : [ 1.0000000e+00 -1.2654226e-06  9.8084897e-08  1.9641726e-04]
# Cube's linear velocity is : [ 3.8102575e-04 -6.9489033e-04 -9.4514515e-05]

# %%
# Cleanup application
simulation_app.close()
